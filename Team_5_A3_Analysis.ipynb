# %% [markdown]
# <strong>Importing the necessary python packages that are needed for the analysis</strong>

# %%
import pandas                as pd                      # data science essentials
import matplotlib.pyplot     as plt                     # fundamental data visualization
import seaborn               as sns                     # enhanced visualization
from sklearn.preprocessing   import StandardScaler      # standard scaler
from sklearn.decomposition   import PCA                 # pca
from scipy.cluster.hierarchy import dendrogram, linkage # dendrograms
from sklearn.cluster         import KMeans              # k-means clustering

# %% [markdown]
# <br><br><br><strong>Running the User defined functions that will be used throughout our analysis</strong>

# %%
########################################
# scree_plot
########################################
def scree_plot(pca_object, export = False):
    # building a scree plot

    # setting plot size
    fig, ax = plt.subplots(figsize=(10, 8))
    features = range(pca_object.n_components_)


    # developing a scree plot
    plt.plot(features,
             pca_object.explained_variance_ratio_,
             linewidth = 2,
             marker = 'o',
             markersize = 10,
             markeredgecolor = 'black',
             markerfacecolor = 'grey')


    # setting more plot options
    plt.title('Scree Plot')
    plt.xlabel('PCA feature')
    plt.ylabel('Explained Variance')
    plt.xticks(features)

    if export == True:
    
        # exporting the plot
        plt.savefig('scree_plot.png')
        
    # displaying the plot
    plt.show()

    
########################################
# inertia plot
########################################
def inertia_plot(data, max_clust = 50):
    """
PARAMETERS
----------
data      : DataFrame, data from which to build clusters. Dataset should be scaled
max_clust : int, maximum of range for how many clusters to check interia, default 50
    """

    ks = range(1, max_clust)
    inertias = []


    for k in ks:
        # INSTANTIATING a kmeans object
        model = KMeans(n_clusters = k)


        # FITTING to the data
        model.fit(data)


        # append each inertia to the list of inertias
        inertias.append(model.inertia_)



    # plotting ks vs inertias
    fig, ax = plt.subplots(figsize = (12, 8))
    plt.plot(ks, inertias, '-o')


    # labeling and displaying the plot
    plt.xlabel('number of clusters, k')
    plt.ylabel('inertia')
    plt.xticks(ks)
    plt.show()

# %% [markdown]
# <br><br><br>
# ***
# ***
# ***
# <h3>Explanatory Data Analysis</h3>
#
# ***
# ***
# ***

# %% [markdown]
# <br><br><br><strong>Loading the original dataset</strong>

# %%
original_df = pd.read_excel('Survey_Data_Final_Exam.xlsx')

#Viewing the dataset 
original_df
# Out:
#     surveyID  Am the life of the party  Feel little concern for others  \
# 0      a1000                         4                               3
# 1      a1001                         2                               4
# 2      a1002                         4                               4
# 3      a1003                         4                               5
# 4      a1004                         5                               4
# ..       ...                       ...                             ...
# 387    a1387                         2                               2
# 388    a1388                         1                               3
# 389    a1389                         2                               4
# 390    a1390                         4                               5
# 391    a1391                         2                               2
#
#      Am always prepared  Get stressed out easily  Have a rich vocabulary  \
# 0                     4                        3                       4
# 1                     3                        4                       3
# 2                     5                        1                       4
# 3                     3                        3                       3
# 4                     4                        4                       3
# ..                  ...                      ...                     ...
# 387                   5                        1                       4
# 388                   3                        4                       4
# 389                   4                        1                       1
# 390                   4                        1                       5
# 391                   3                        2                       2
#
#      Don't talk a lot  Am interested in people  Leave my belongings around  \
# 0                   2                        3                           2
# 1                   3                        2                           3
# 2                   3                        2                           2
# 3                   3                        5                           3
# 4                   3                        3                           3
# ..                ...                      ...                         ...
# 387                 5                        5                           2
# 388                 4                        3                           1
# 389                 4                        5                           3
# 390                 1                        4                           1
# 391                 3                        4                           2
#
#      Am relaxed most of the time  ...  Seek and use feedback from teammates  \
# 0                              3  ...                                     4
# 1                              4  ...                                     5
# 2                              5  ...                                     3
# 3                              5  ...                                     5
# 4                              3  ...                                     3
# ..                           ...  ...                                   ...
# 387                            4  ...                                     3
# 388                            2  ...                                     4
# 389                            5  ...                                     5
# 390                            5  ...                                     5
# 391                            3  ...                                     2
#
#      Coach teammates for performance and growth  Drive for results  \
# 0                                             4                  4
# 1                                             4                  5
# 2                                             3                  5
# 3                                             5                  5
# 4                                             3                  3
# ..                                          ...                ...
# 387                                           3                  4
# 388                                           4                  4
# 389                                           5                  5
# 390                                           5                  5
# 391                                           3                  4
#
#      What laptop do you currently have?  \
# 0                               Macbook
# 1                        Windows laptop
# 2                        Windows laptop
# 3                        Windows laptop
# 4                               Macbook
# ..                                  ...
# 387                      Windows laptop
# 388                             Macbook
# 389                      Windows laptop
# 390                      Windows laptop
# 391                      Windows laptop
#
#      What laptop would you buy in next assuming if all laptops cost the same?  \
# 0                                              Macbook
# 1                                       Windows laptop
# 2                                       Windows laptop
# 3                                       Windows laptop
# 4                                       Windows laptop
# ..                                                 ...
# 387                                     Windows laptop
# 388                                            Macbook
# 389                                            Macbook
# 390                                     Windows laptop
# 391                                     Windows laptop
#
#              What program are you in?  What is your age?  Gender  \
# 0       DD (MIB & Business Analytics)                 25  Female
# 1         One year Business Analytics                 27    Male
# 2         One year Business Analytics                 25    Male
# 3         One year Business Analytics                 26  Female
# 4    DD (MBA & Disruptive innovation)                 27    Male
# ..                                ...                ...     ...
# 387     DD (MBA & Business Analytics)                 37    Male
# 388     DD (MIB & Business Analytics)                 27  Female
# 389     DD (MIB & Business Analytics)                 23    Male
# 390     DD (MIB & Business Analytics)                 25    Male
# 391       One year Business Analytics                 27  Female
#
#      What is your nationality?   What is your ethnicity?
# 0                       ecuador        Hispanic / Latino
# 1                       Ecuador        Hispanic / Latino
# 2                        Indian      West Asian / Indian
# 3                        indian      West Asian / Indian
# 4                         China           Far east Asian
# ..                          ...                      ...
# 387                        calm        Hispanic / Latino
# 388                           .        White / Caucasian
# 389                       India      West Asian / Indian
# 390                      INDIAN      West Asian / Indian
# 391                        Thai           Far east Asian
#
# [392 rows x 79 columns]

# %%
#Finding the info of the dataframe
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 79 columns):
# surveyID                                                                        392 non-null object
# Am the life of the party                                                        392 non-null int64
# Feel little concern for others                                                  392 non-null int64
# Am always prepared                                                              392 non-null int64
# Get stressed out easily                                                         392 non-null int64
# Have a rich vocabulary                                                          392 non-null int64
# Don't talk a lot                                                                392 non-null int64
# Am interested in people                                                         392 non-null int64
# Leave my belongings around                                                      392 non-null int64
# Am relaxed most of the time                                                     392 non-null int64
# Have difficulty understanding abstract ideas                                    392 non-null int64
# Feel comfortable around people                                                  392 non-null int64
# Insult people                                                                   392 non-null int64
# Pay attention to details                                                        392 non-null int64
# Worry about things                                                              392 non-null int64
# Have a vivid imagination                                                        392 non-null int64
# Keep in the background                                                          392 non-null int64
# Sympathize with others' feelings                                                392 non-null int64
# Make a mess of things                                                           392 non-null int64
# Seldom feel blue                                                                392 non-null int64
# Am not interested in abstract ideas                                             392 non-null int64
# Start conversations                                                             392 non-null int64
# Am not interested in other people's problems                                    392 non-null int64
# Get chores done right away                                                      392 non-null int64
# Am easily disturbed                                                             392 non-null int64
# Have excellent ideas                                                            392 non-null int64
# Have little to say                                                              392 non-null int64
# Have a soft heart                                                               392 non-null int64
# Often forget to put things back in their proper place                           392 non-null int64
# Get upset easily                                                                392 non-null int64
# Do not have a good imagination                                                  392 non-null int64
# Talk to a lot of different people at parties                                    392 non-null int64
# Am not really interested in others                                              392 non-null int64
# Like order                                                                      392 non-null int64
# Change my mood a lot                                                            392 non-null int64
# Am quick to understand things                                                   392 non-null int64
# Don't like to draw attention to myself                                          392 non-null int64
# Take time out for others                                                        392 non-null int64
# Shirk my duties                                                                 392 non-null int64
# Have frequent mood swings                                                       392 non-null int64
# Use difficult words                                                             392 non-null int64
# Don't mind being the center of attention                                        392 non-null int64
# Feel others' emotions                                                           392 non-null int64
# Follow a schedule                                                               392 non-null int64
# Get irritated easily                                                            392 non-null int64
# Spend time reflecting on things                                                 392 non-null int64
# Am quiet around strangers                                                       392 non-null int64
# Make people feel at ease                                                        392 non-null int64
# Am exacting in my work                                                          392 non-null int64
# Often feel blue                                                                 392 non-null int64
# Am full of ideas                                                                392 non-null int64
# See underlying patterns in complex situations                                   392 non-null int64
# Don't  generate ideas that are new and different                                392 non-null int64
# Demonstrate an awareness of personal strengths and limitations                  392 non-null int64
# Display a growth mindset                                                        392 non-null int64
# Respond effectively to multiple priorities                                      392 non-null int64
# Take initiative even when circumstances, objectives, or rules aren't clear      392 non-null int64
# Encourage direct and open discussions                                           392 non-null int64
# Respond effectively to multiple priorities.1                                    392 non-null int64
# Take initiative even when circumstances, objectives, or rules aren't clear.1    392 non-null int64
# Encourage direct and open discussions.1                                         392 non-null int64
# Listen carefully to others                                                      392 non-null int64
# Don't persuasively sell a vision or idea                                        392 non-null int64
# Build cooperative relationships                                                 392 non-null int64
# Work well with people from diverse cultural backgrounds                         392 non-null int64
# Effectively negotiate interests, resources, and roles                           392 non-null int64
# Can't rally people on the team around a common goal                             392 non-null int64
# Translate ideas into plans that are organized and realistic                     392 non-null int64
# Resolve conflicts constructively                                                392 non-null int64
# Seek and use feedback from teammates                                            392 non-null int64
# Coach teammates for performance and growth                                      392 non-null int64
# Drive for results                                                               392 non-null int64
# What laptop do you currently have?                                              392 non-null object
# What laptop would you buy in next assuming if all laptops cost the same?        392 non-null object
# What program are you in?                                                        392 non-null object
# What is your age?                                                               392 non-null int64
# Gender                                                                          392 non-null object
# What is your nationality?                                                       392 non-null object
# What is your ethnicity?                                                         391 non-null object
# dtypes: int64(72), object(7)
# memory usage: 242.1+ KB

# %%
#Checking to see if any columns have missing values and summing them up to find the total of missing values
original_df.isnull().any().sum()
# Out:
# 1

# %%
#Looking at the value that is missing 
original_df['What is your ethnicity?'][original_df['What is your ethnicity?'].isnull()]
# Out:
# 147    NaN
# Name: What is your ethnicity?, dtype: object

# %%
#Looking at all the other columns of the missing row
print(original_df.iloc[147, :])
# Out:
# surveyID                                                a1147
# Am the life of the party                                    3
# Feel little concern for others                              4
# Am always prepared                                          4
# Get stressed out easily                                     5
#                                              ...
# What program are you in?          One year Business Analytics
# What is your age?                                          45
# Gender                                                   Male
# What is your nationality?                                 USA
# What is your ethnicity?                                   NaN
# Name: 147, Length: 79, dtype: object

# %% [markdown]
# <strong>Question: </strong>How is this guy 45 years old? Fake observation or someone just playing around?

# %%
#Filling the missing value 
original_df.fillna('Unanswered', inplace = True)

# %%
#Rechecking if any missing value exists
original_df.isnull().any().sum()
# Out:
# 0

# %%
#Finding the descriptive statistics of the dataset
original_df.loc[:, :].describe().round(2)
# Out:
#        Am the life of the party  Feel little concern for others  \
# count                    392.00                          392.00
# mean                       2.94                            2.76
# std                        1.12                            1.31
# min                        1.00                            1.00
# 25%                        2.00                            2.00
# 50%                        3.00                            3.00
# 75%                        4.00                            4.00
# max                        5.00                            5.00
#
#        Am always prepared  Get stressed out easily  Have a rich vocabulary  \
# count              392.00                   392.00                  392.00
# mean                 3.57                     2.91                    3.31
# std                  0.89                     1.23                    0.95
# min                  1.00                     1.00                    1.00
# 25%                  3.00                     2.00                    3.00
# 50%                  4.00                     3.00                    3.00
# 75%                  4.00                     4.00                    4.00
# max                  5.00                     5.00                    5.00
#
#        Don't talk a lot  Am interested in people  Leave my belongings around  \
# count            392.00                   392.00                      392.00
# mean               2.90                     3.83                        2.43
# std                1.14                     0.99                        1.36
# min                1.00                     1.00                        1.00
# 25%                2.00                     3.00                        1.00
# 50%                3.00                     4.00                        2.00
# 75%                4.00                     5.00                        3.00
# max                5.00                     5.00                        5.00
#
#        Am relaxed most of the time  \
# count                       392.00
# mean                          3.30
# std                           1.09
# min                           1.00
# 25%                           2.00
# 50%                           3.00
# 75%                           4.00
# max                           5.00
#
#        Have difficulty understanding abstract ideas  ...  \
# count                                        392.00  ...
# mean                                           2.41  ...
# std                                            1.10  ...
# min                                            1.00  ...
# 25%                                            2.00  ...
# 50%                                            2.00  ...
# 75%                                            3.00  ...
# max                                            5.00  ...
#
#        Build cooperative relationships  \
# count                           392.00
# mean                              4.12
# std                               0.76
# min                               1.00
# 25%                               4.00
# 50%                               4.00
# 75%                               5.00
# max                               5.00
#
#        Work well with people from diverse cultural backgrounds  \
# count                                             392.00
# mean                                                4.26
# std                                                 0.68
# min                                                 2.00
# 25%                                                 4.00
# 50%                                                 4.00
# 75%                                                 5.00
# max                                                 5.00
#
#        Effectively negotiate interests, resources, and roles  \
# count                                             392.00
# mean                                                3.94
# std                                                 0.77
# min                                                 2.00
# 25%                                                 3.00
# 50%                                                 4.00
# 75%                                                 4.00
# max                                                 5.00
#
#        Can't rally people on the team around a common goal  \
# count                                             392.00
# mean                                                2.51
# std                                                 1.10
# min                                                 1.00
# 25%                                                 2.00
# 50%                                                 2.00
# 75%                                                 3.00
# max                                                 5.00
#
#        Translate ideas into plans that are organized and realistic  \
# count                                             392.00
# mean                                                3.91
# std                                                 0.79
# min                                                 2.00
# 25%                                                 3.00
# 50%                                                 4.00
# 75%                                                 4.00
# max                                                 5.00
#
#        Resolve conflicts constructively  Seek and use feedback from teammates  \
# count                            392.00                                392.00
# mean                               3.94                                  4.06
# std                                0.73                                  0.80
# min                                2.00                                  2.00
# 25%                                4.00                                  4.00
# 50%                                4.00                                  4.00
# 75%                                4.00                                  5.00
# max                                5.00                                  5.00
#
#        Coach teammates for performance and growth  Drive for results  \
# count                                      392.00             392.00
# mean                                         3.76               4.28
# std                                          0.88               0.75
# min                                          1.00               1.00
# 25%                                          3.00               4.00
# 50%                                          4.00               4.00
# 75%                                          4.00               5.00
# max                                          5.00               5.00
#
#        What is your age?
# count             392.00
# mean               27.34
# std                 5.34
# min                15.00
# 25%                24.00
# 50%                26.00
# 75%                29.00
# max                51.00
#
# [8 rows x 72 columns]

# %%
#Renaming the columns for easier identificaition and usage
original_df.columns = ['surveyID', 
                       'life_of_the_party', 
                       'unconcerned_for_others', 
                       'always_prepared', 
                       'stressed_out_easily', 
                       'have_rich_vocabulary', 
                       'less_talkative', 
                       'interested_in_people', 
                       'leave_belongings_around', 
                       'relaxed', 
                       'difficulty_understanding_abstract_ideas', 
                       'comfortable_around_people', 
                       'insult_people', 
                       'attention_to_detail',
                       'worrisome', 
                       'vivid_imagination', 
                       'keep_in_the_background', 
                       'sympathetic', 
                       'messy_person', 
                       'seldom_feel_blue', 
                       'uninterested_in_abstract_ideas', 
                       'starts_conversations', 
                       'uninterested_in_peoples_problems', 
                       'get_chores_done', 
                       'easily_disturbed', 
                       'have_excellent_ideas', 
                       'have_little_to_say', 
                       'soft_hearted', 
                       'forget_to_put_things_back', 
                       'get_upset_easily', 
                       'no_good_imagination', 
                       'socialize_at_parties', 
                       'uninterested_in_others', 
                       'like_order', 
                       'moody', 
                       'quick_at_understanding_things', 
                       'averts_attention_to_self', 
                       'take_time_out_for_others', 
                       'avoids_duties', 
                       'mood_swings',
                       'use_difficult_words', 
                       'likes_being_center_of_attention', 
                       'feel_others_emotions', 
                       'follows_schedule', 
                       'irritated_easily', 
                       'reflects_on_things', 
                       'quite_around_strangers', 
                       'make_people_feel_at_ease', 
                       'exacting_at_work', 
                       'feels_blue', 
                       'full_of_ideas', 
                       'sees_underlying_patters_in_complex_situations', 
                       'dont_generate_new_ideas',
                       'aware_of_personal_strengths/weakness', 
                       'growth_mindset', 
                       'responds_effectively_to_priorities', 
                       'takes_initiative', 
                       'encourages_direct/open_discussions', 
                       'responds_effectively_to_priorities(duplicate)', 
                       'takes_initiative(duplicate)', 
                       'encourages_direct/open_discussions(duplicate)', 
                       'good_listener', 
                       'dont_persuasively_sell_vision/idea', 
                       'builds_cooperative_relationships', 
                       'works_well_with_people_from_diverse_cultures', 
                       'effectively_negotiates_interests/resources/roles', 
                       'cant_rally_team_towards_common_goal', 
                       'translates_ideas_into_plans_that_are_organized/realistic', 
                       'resolves_conflicts_constructively', 
                       'seeks/uses_teammates_feedback', 
                       'coaches_teammates_for_performance/growth', 
                       'drive_for_results', 
                       'current_laptop', 
                       'preferred_laptop', 
                       'program', 
                       'age', 
                       'gender',
                       'nationality', 
                       'ethnicity']

# %%
#Finding the value counts of categorical variables
print(original_df.loc[:, 'current_laptop'].value_counts())
print("\n")
print(original_df.loc[:, 'preferred_laptop'].value_counts())
print("\n")
print(original_df.loc[:, 'program'].value_counts())
print("\n")
print(original_df.loc[:, 'gender'].value_counts())
print("\n")
print(original_df.loc[:, 'nationality'].value_counts())
print("\n")
print(original_df.loc[:, 'ethnicity'].value_counts())
# Out:
# Macbook           199
# Windows laptop    192
# MAC                 1
# Name: current_laptop, dtype: int64
#
#
# Macbook           218
# Windows laptop    163
# Chromebook         10
# MAC                 1
# Name: preferred_laptop, dtype: int64
#
#
# DD (MIB & Business Analytics)       198
# One year Business Analytics          99
# DD (MBA & Business Analytics)        93
# DD (MBA & Disruptive innovation)      2
# Name: program, dtype: int64
#
#
# Male      227
# Female    165
# Name: gender, dtype: int64
#
#
# Indian       51
# China        28
# German       17
# Mexican      14
# Peruvian     11
#              ..
# .             1
# Dutch         1
# Mexico        1
# Korean        1
# Venezuela     1
# Name: nationality, Length: 106, dtype: int64
#
#
# White / Caucasian       98
# Far east Asian          85
# West Asian / Indian     77
# Hispanic / Latino       70
# Prefer not to answer    31
# African American        21
# Middle Eastern           7
# Native American          2
# Unanswered               1
# Name: ethnicity, dtype: int64

# %%
#Analysis of current laptop brand per answer

current_laptop = original_df.loc[:, 'current_laptop']

current_windows = 0
current_macbook = 0
current_chromebook = 0
current_total = 0

for brand in current_laptop:
    if brand == "Windows laptop":
        current_windows += 1
        current_total += 1
    
    elif brand == 'Chromebook':
        current_chromebook += 1
        current_total += 1
        
    else:
        current_macbook += 1
        current_total += 1

perc_windows = round((current_windows/current_total) * 100, 1)
perc_macbook = round((current_macbook/current_total) * 100, 1)
perc_chromebook = round((current_chromebook/current_total) * 100, 1)

print(f"""
        Total computers:           {current_total}
        Total current Windows:     {current_windows}, a {perc_windows}% of the total.
        Total current Macbooks:    {current_macbook}, a {perc_macbook}% of the total.
        Total current Chromebooks: {current_chromebook}, a {perc_chromebook}% of the total.
        _____________________________________________________
        """)
# Out:
#         Total computers:           392
#         Total current Windows:     192, a 49.0% of the total.
#         Total current Macbooks:    200, a 51.0% of the total.
#         Total current Chromebooks: 0, a 0.0% of the total.
#         _____________________________________________________

# %%
#Analysis of preferred laptop brand per answer

preferred_laptop_laptop = original_df.loc[:, 'preferred_laptop']

preferred_laptop_windows = 0
preferred_laptop_macbook = 0
preferred_laptop_chromebook = 0
preferred_laptop_total = 0

for brand in preferred_laptop_laptop:
    if brand == "Windows laptop":
        preferred_laptop_windows += 1
        preferred_laptop_total += 1
    
    elif brand == 'Chromebook':
        preferred_laptop_chromebook += 1
        preferred_laptop_total += 1
        
    else:
        preferred_laptop_macbook += 1
        preferred_laptop_total += 1

diff_wind = preferred_laptop_windows - current_windows
diff_mac = preferred_laptop_macbook - current_macbook

change_windows = round(((preferred_laptop_windows - current_windows)/current_windows) * 100, 1)
change_macbook = round(((preferred_laptop_macbook - current_macbook)/current_macbook) * 100, 1)
#change_chromebook = round((preferred_laptop_chromebook/target_total) * 100, 1)


print(f"""
        Total computers:             {preferred_laptop_total}
        Total preferred Windows:     {preferred_laptop_windows}, a change of {diff_wind} units ({change_windows}%).
        Total preferred Macbooks:    {preferred_laptop_macbook}, a change of {diff_mac} units ({change_macbook}%).
        Total preferred Chromebooks:  {preferred_laptop_chromebook}, a new player!
        _____________________________________________________
        """)
# Out:
#         Total computers:             392
#         Total preferred Windows:     163, a change of -29 units (-15.1%).
#         Total preferred Macbooks:    219, a change of 19 units (9.5%).
#         Total preferred Chromebooks:  10, a new player!
#         _____________________________________________________

# %% [markdown]
# <strong>INSIGHT:</strong><br>
# When it comes to branding and operating system, the sample is evenly distributed. In this sense, 51% of the survey owns a Macbook (200 people), and 49% have a Windows laptop. However, in the context of all devices having the same retail price, the distribution would change as follows: Macbook would increase by 19 units (56% of total), Windows would decrease by 29 units (41.5% of total), and Chromebook would have 10 units (2.5%). Note that although Macbook increased in total units, it would lose 16 users to Windows, and 3 users to Chromebook.

# %% [markdown]
# <br><br><br><strong>To maintain the similarity between features as required in Unsupervised learning, dropping variables that do not match with the survey questions, where people gave a rating between 1 and 5</strong>

# %%
survey_answers = original_df.drop(['surveyID', 'current_laptop', 'preferred_laptop', 'program', 'age', 'gender',
                                   'nationality', 'ethnicity'], axis = 1)

#Viewing the new dataset
survey_answers
# Out:
#      life_of_the_party  unconcerned_for_others  always_prepared  \
# 0                    4                       3                4
# 1                    2                       4                3
# 2                    4                       4                5
# 3                    4                       5                3
# 4                    5                       4                4
# ..                 ...                     ...              ...
# 387                  2                       2                5
# 388                  1                       3                3
# 389                  2                       4                4
# 390                  4                       5                4
# 391                  2                       2                3
#
#      stressed_out_easily  have_rich_vocabulary  less_talkative  \
# 0                      3                     4               2
# 1                      4                     3               3
# 2                      1                     4               3
# 3                      3                     3               3
# 4                      4                     3               3
# ..                   ...                   ...             ...
# 387                    1                     4               5
# 388                    4                     4               4
# 389                    1                     1               4
# 390                    1                     5               1
# 391                    2                     2               3
#
#      interested_in_people  leave_belongings_around  relaxed  \
# 0                       3                        2        3
# 1                       2                        3        4
# 2                       2                        2        5
# 3                       5                        3        5
# 4                       3                        3        3
# ..                    ...                      ...      ...
# 387                     5                        2        4
# 388                     3                        1        2
# 389                     5                        3        5
# 390                     4                        1        5
# 391                     4                        2        3
#
#      difficulty_understanding_abstract_ideas  ...  \
# 0                                          2  ...
# 1                                          2  ...
# 2                                          1  ...
# 3                                          4  ...
# 4                                          3  ...
# ..                                       ...  ...
# 387                                        2  ...
# 388                                        4  ...
# 389                                        5  ...
# 390                                        3  ...
# 391                                        2  ...
#
#      dont_persuasively_sell_vision/idea  builds_cooperative_relationships  \
# 0                                     3                                 4
# 1                                     2                                 4
# 2                                     2                                 3
# 3                                     3                                 5
# 4                                     4                                 3
# ..                                  ...                               ...
# 387                                   2                                 4
# 388                                   2                                 4
# 389                                   3                                 5
# 390                                   4                                 5
# 391                                   3                                 4
#
#      works_well_with_people_from_diverse_cultures  \
# 0                                               4
# 1                                               4
# 2                                               4
# 3                                               5
# 4                                               3
# ..                                            ...
# 387                                             4
# 388                                             4
# 389                                             4
# 390                                             5
# 391                                             4
#
#      effectively_negotiates_interests/resources/roles  \
# 0                                                   4
# 1                                                   2
# 2                                                   4
# 3                                                   5
# 4                                                   4
# ..                                                ...
# 387                                                 3
# 388                                                 4
# 389                                                 5
# 390                                                 5
# 391                                                 4
#
#      cant_rally_team_towards_common_goal  \
# 0                                      2
# 1                                      3
# 2                                      2
# 3                                      5
# 4                                      4
# ..                                   ...
# 387                                    3
# 388                                    4
# 389                                    5
# 390                                    1
# 391                                    1
#
#      translates_ideas_into_plans_that_are_organized/realistic  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 387                                                  4
# 388                                                  4
# 389                                                  5
# 390                                                  5
# 391                                                  3
#
#      resolves_conflicts_constructively  seeks/uses_teammates_feedback  \
# 0                                    4                              4
# 1                                    5                              5
# 2                                    2                              3
# 3                                    5                              5
# 4                                    3                              3
# ..                                 ...                            ...
# 387                                  4                              3
# 388                                  4                              4
# 389                                  5                              5
# 390                                  5                              5
# 391                                  2                              2
#
#      coaches_teammates_for_performance/growth  drive_for_results
# 0                                           4                  4
# 1                                           4                  5
# 2                                           3                  5
# 3                                           5                  5
# 4                                           3                  3
# ..                                        ...                ...
# 387                                         3                  4
# 388                                         4                  4
# 389                                         5                  5
# 390                                         5                  5
# 391                                         3                  4
#
# [392 rows x 71 columns]

# %% [markdown]
# <br><br><strong>Separating columns that relate to Big 5 personality traits and Hult DNA.</strong>

# %%
#Subsetting the Big5 personality traits
survey_answers_big5 =   survey_answers.loc[:, ['life_of_the_party', 
                                               'unconcerned_for_others', 
                                               'always_prepared', 
                                               'stressed_out_easily', 
                                               'have_rich_vocabulary', 
                                               'less_talkative', 
                                               'interested_in_people', 
                                               'leave_belongings_around', 
                                               'relaxed', 
                                               'difficulty_understanding_abstract_ideas', 
                                               'comfortable_around_people', 
                                               'insult_people', 
                                               'attention_to_detail',
                                               'worrisome', 
                                               'vivid_imagination', 
                                               'keep_in_the_background', 
                                               'sympathetic', 
                                               'messy_person', 
                                               'seldom_feel_blue', 
                                               'uninterested_in_abstract_ideas', 
                                               'starts_conversations', 
                                               'uninterested_in_peoples_problems', 
                                               'get_chores_done', 
                                               'easily_disturbed', 
                                               'have_excellent_ideas', 
                                               'have_little_to_say', 
                                               'soft_hearted', 
                                               'forget_to_put_things_back', 
                                               'get_upset_easily', 
                                               'no_good_imagination', 
                                               'socialize_at_parties', 
                                               'uninterested_in_others', 
                                               'like_order', 
                                               'moody', 
                                               'quick_at_understanding_things', 
                                               'averts_attention_to_self', 
                                               'take_time_out_for_others', 
                                               'avoids_duties', 
                                               'mood_swings',
                                               'use_difficult_words', 
                                               'likes_being_center_of_attention', 
                                               'feel_others_emotions', 
                                               'follows_schedule', 
                                               'irritated_easily', 
                                               'reflects_on_things', 
                                               'quite_around_strangers', 
                                               'make_people_feel_at_ease', 
                                               'exacting_at_work', 
                                               'feels_blue', 
                                               'full_of_ideas']]

#Checking the results
survey_answers_big5
# Out:
#      life_of_the_party  unconcerned_for_others  always_prepared  \
# 0                    4                       3                4
# 1                    2                       4                3
# 2                    4                       4                5
# 3                    4                       5                3
# 4                    5                       4                4
# ..                 ...                     ...              ...
# 387                  2                       2                5
# 388                  1                       3                3
# 389                  2                       4                4
# 390                  4                       5                4
# 391                  2                       2                3
#
#      stressed_out_easily  have_rich_vocabulary  less_talkative  \
# 0                      3                     4               2
# 1                      4                     3               3
# 2                      1                     4               3
# 3                      3                     3               3
# 4                      4                     3               3
# ..                   ...                   ...             ...
# 387                    1                     4               5
# 388                    4                     4               4
# 389                    1                     1               4
# 390                    1                     5               1
# 391                    2                     2               3
#
#      interested_in_people  leave_belongings_around  relaxed  \
# 0                       3                        2        3
# 1                       2                        3        4
# 2                       2                        2        5
# 3                       5                        3        5
# 4                       3                        3        3
# ..                    ...                      ...      ...
# 387                     5                        2        4
# 388                     3                        1        2
# 389                     5                        3        5
# 390                     4                        1        5
# 391                     4                        2        3
#
#      difficulty_understanding_abstract_ideas  ...  \
# 0                                          2  ...
# 1                                          2  ...
# 2                                          1  ...
# 3                                          4  ...
# 4                                          3  ...
# ..                                       ...  ...
# 387                                        2  ...
# 388                                        4  ...
# 389                                        5  ...
# 390                                        3  ...
# 391                                        2  ...
#
#      likes_being_center_of_attention  feel_others_emotions  follows_schedule  \
# 0                                  3                     3                 4
# 1                                  2                     3                 5
# 2                                  5                     3                 4
# 3                                  2                     5                 3
# 4                                  4                     4                 4
# ..                               ...                   ...               ...
# 387                                2                     4                 5
# 388                                3                     3                 3
# 389                                5                     5                 5
# 390                                3                     5                 5
# 391                                1                     4                 2
#
#      irritated_easily  reflects_on_things  quite_around_strangers  \
# 0                   2                   4                       3
# 1                   4                   5                       4
# 2                   4                   2                       3
# 3                   5                   5                       3
# 4                   3                   3                       3
# ..                ...                 ...                     ...
# 387                 3                   5                       2
# 388                 3                   4                       4
# 389                 1                   5                       5
# 390                 1                   4                       1
# 391                 3                   1                       5
#
#      make_people_feel_at_ease  exacting_at_work  feels_blue  full_of_ideas
# 0                           3                 4           2              3
# 1                           5                 5           3              4
# 2                           3                 3           1              4
# 3                           5                 3           3              5
# 4                           3                 4           4              3
# ..                        ...               ...         ...            ...
# 387                         4                 5           2              4
# 388                         4                 4           3              4
# 389                         5                 5           1              5
# 390                         5                 5           1              5
# 391                         3                 5           2              3
#
# [392 rows x 50 columns]

# %%
#Choosing columns with Hult DNA
survey_answers_hultdna = survey_answers.loc[:,['sees_underlying_patters_in_complex_situations', 
                                               'dont_generate_new_ideas',
                                               'aware_of_personal_strengths/weakness', 
                                               'growth_mindset', 
                                               'responds_effectively_to_priorities', 
                                               'takes_initiative', 
                                               'encourages_direct/open_discussions', 
                                               'responds_effectively_to_priorities(duplicate)', 
                                               'takes_initiative(duplicate)', 
                                               'encourages_direct/open_discussions(duplicate)', 
                                               'good_listener', 
                                               'dont_persuasively_sell_vision/idea', 
                                               'builds_cooperative_relationships', 
                                               'works_well_with_people_from_diverse_cultures', 
                                               'effectively_negotiates_interests/resources/roles', 
                                               'cant_rally_team_towards_common_goal', 
                                               'translates_ideas_into_plans_that_are_organized/realistic', 
                                               'resolves_conflicts_constructively', 
                                               'seeks/uses_teammates_feedback', 
                                               'coaches_teammates_for_performance/growth', 
                                               'drive_for_results']]

#Checking the dataset
survey_answers_hultdna
# Out:
#      sees_underlying_patters_in_complex_situations  dont_generate_new_ideas  \
# 0                                                4                        2
# 1                                                4                        2
# 2                                                3                        2
# 3                                                3                        3
# 4                                                3                        3
# ..                                             ...                      ...
# 387                                              3                        2
# 388                                              4                        4
# 389                                              5                        1
# 390                                              5                        1
# 391                                              4                        2
#
#      aware_of_personal_strengths/weakness  growth_mindset  \
# 0                                       4               4
# 1                                       2               4
# 2                                       5               3
# 3                                       3               5
# 4                                       5               3
# ..                                    ...             ...
# 387                                     4               4
# 388                                     4               4
# 389                                     5               5
# 390                                     3               5
# 391                                     4               5
#
#      responds_effectively_to_priorities  takes_initiative  \
# 0                                     4                 4
# 1                                     4                 4
# 2                                     5                 2
# 3                                     5                 5
# 4                                     3                 3
# ..                                  ...               ...
# 387                                   3                 3
# 388                                   4                 4
# 389                                   5                 5
# 390                                   5                 4
# 391                                   4                 2
#
#      encourages_direct/open_discussions  \
# 0                                     4
# 1                                     5
# 2                                     3
# 3                                     4
# 4                                     3
# ..                                  ...
# 387                                   3
# 388                                   4
# 389                                   5
# 390                                   5
# 391                                   4
#
#      responds_effectively_to_priorities(duplicate)  \
# 0                                                4
# 1                                                5
# 2                                                5
# 3                                                4
# 4                                                3
# ..                                             ...
# 387                                              4
# 388                                              4
# 389                                              5
# 390                                              5
# 391                                              4
#
#      takes_initiative(duplicate)  \
# 0                              4
# 1                              5
# 2                              2
# 3                              4
# 4                              3
# ..                           ...
# 387                            4
# 388                            4
# 389                            5
# 390                            4
# 391                            2
#
#      encourages_direct/open_discussions(duplicate)  ...  \
# 0                                                4  ...
# 1                                                5  ...
# 2                                                3  ...
# 3                                                4  ...
# 4                                                4  ...
# ..                                             ...  ...
# 387                                              4  ...
# 388                                              4  ...
# 389                                              5  ...
# 390                                              5  ...
# 391                                              4  ...
#
#      dont_persuasively_sell_vision/idea  builds_cooperative_relationships  \
# 0                                     3                                 4
# 1                                     2                                 4
# 2                                     2                                 3
# 3                                     3                                 5
# 4                                     4                                 3
# ..                                  ...                               ...
# 387                                   2                                 4
# 388                                   2                                 4
# 389                                   3                                 5
# 390                                   4                                 5
# 391                                   3                                 4
#
#      works_well_with_people_from_diverse_cultures  \
# 0                                               4
# 1                                               4
# 2                                               4
# 3                                               5
# 4                                               3
# ..                                            ...
# 387                                             4
# 388                                             4
# 389                                             4
# 390                                             5
# 391                                             4
#
#      effectively_negotiates_interests/resources/roles  \
# 0                                                   4
# 1                                                   2
# 2                                                   4
# 3                                                   5
# 4                                                   4
# ..                                                ...
# 387                                                 3
# 388                                                 4
# 389                                                 5
# 390                                                 5
# 391                                                 4
#
#      cant_rally_team_towards_common_goal  \
# 0                                      2
# 1                                      3
# 2                                      2
# 3                                      5
# 4                                      4
# ..                                   ...
# 387                                    3
# 388                                    4
# 389                                    5
# 390                                    1
# 391                                    1
#
#      translates_ideas_into_plans_that_are_organized/realistic  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 387                                                  4
# 388                                                  4
# 389                                                  5
# 390                                                  5
# 391                                                  3
#
#      resolves_conflicts_constructively  seeks/uses_teammates_feedback  \
# 0                                    4                              4
# 1                                    5                              5
# 2                                    2                              3
# 3                                    5                              5
# 4                                    3                              3
# ..                                 ...                            ...
# 387                                  4                              3
# 388                                  4                              4
# 389                                  5                              5
# 390                                  5                              5
# 391                                  2                              2
#
#      coaches_teammates_for_performance/growth  drive_for_results
# 0                                           4                  4
# 1                                           4                  5
# 2                                           3                  5
# 3                                           5                  5
# 4                                           3                  3
# ..                                        ...                ...
# 387                                         3                  4
# 388                                         4                  4
# 389                                         5                  5
# 390                                         5                  5
# 391                                         3                  4
#
# [392 rows x 21 columns]

# %%
#print(survey_answers_hultdna['responds_effectively_to_priorities'].corr(survey_answers_hultdna['responds_effectively_to_priorities(duplicate)']))
#print("\n")
#print(survey_answers_hultdna['takes_initiative'].corr(survey_answers_hultdna['takes_initiative(duplicate)']))
#print("\n")
#print(survey_answers_hultdna['encourages_direct/open_discussions'].corr(survey_answers_hultdna['encourages_direct/open_discussions(duplicate)']))

# %% [markdown]
# <strong>Note:</strong> There are 3 repeated questions, labeled as (duplicates). We will use them as is, since they look highly correlated and the PCA algorithm works fine with highly correlated explanatory variables.

# %% [markdown]
# <br><br><br><strong>Scaling the explanatory variables, so that they can be used in PCA and KNN clustering methods</strong>

# %% [markdown]
# <h4>Scaling the whole survey_answers explanatory variables</h4>

# %%
#Instantiating a StandartScaler object
scaler = StandardScaler()

#Fitting the scaler object to the explanatory data
scaler.fit(survey_answers)

#Transforming the fit data
survey_answers_scaled = scaler.transform(survey_answers)

#Converting into a dataframe object
survey_answers_scaled_df = pd.DataFrame(survey_answers_scaled)

#Renaming the columns 
survey_answers_scaled_df.columns = survey_answers.columns

#Checking the variance before and after scaling
print(pd.np.var(survey_answers))
print("\n")
print(pd.np.var(survey_answers_scaled_df))
# Out:
# life_of_the_party                                           1.246252
# unconcerned_for_others                                      1.712906
# always_prepared                                             0.791174
# stressed_out_easily                                         1.498744
# have_rich_vocabulary                                        0.903139
#                                                               ...
# translates_ideas_into_plans_that_are_organized/realistic    0.620028
# resolves_conflicts_constructively                           0.524619
# seeks/uses_teammates_feedback                               0.641966
# coaches_teammates_for_performance/growth                    0.767694
# drive_for_results                                           0.556747
# Length: 71, dtype: float64
#
#
# life_of_the_party                                           1.0
# unconcerned_for_others                                      1.0
# always_prepared                                             1.0
# stressed_out_easily                                         1.0
# have_rich_vocabulary                                        1.0
#                                                            ...
# translates_ideas_into_plans_that_are_organized/realistic    1.0
# resolves_conflicts_constructively                           1.0
# seeks/uses_teammates_feedback                               1.0
# coaches_teammates_for_performance/growth                    1.0
# drive_for_results                                           1.0
# Length: 71, dtype: float64

# %% [markdown]
# <h4>Scaling the Big5 personality traits explanatory variables</h4>

# %%
#Instantiating a StandartScaler object
scaler = StandardScaler()

#Fitting the scaler object to the explanatory data
scaler.fit(survey_answers_big5)

#Transforming the fit data
survey_answers_big5_scaled = scaler.transform(survey_answers_big5)

#Converting into a dataframe object
survey_answers_big5_scaled_df = pd.DataFrame(survey_answers_big5_scaled)

#Renaming the columns 
survey_answers_big5_scaled_df.columns = survey_answers_big5.columns

#Checking the variance before and after scaling
print(pd.np.var(survey_answers_big5))
print("\n")
print(pd.np.var(survey_answers_big5_scaled_df))
# Out:
# life_of_the_party                          1.246252
# unconcerned_for_others                     1.712906
# always_prepared                            0.791174
# stressed_out_easily                        1.498744
# have_rich_vocabulary                       0.903139
# less_talkative                             1.300812
# interested_in_people                       0.976754
# leave_belongings_around                    1.832335
# relaxed                                    1.191008
# difficulty_understanding_abstract_ideas    1.200275
# comfortable_around_people                  0.988312
# insult_people                              0.924511
# attention_to_detail                        0.686355
# worrisome                                  1.267538
# vivid_imagination                          0.869579
# keep_in_the_background                     1.012911
# sympathetic                                0.737401
# messy_person                               1.166174
# seldom_feel_blue                           1.082355
# uninterested_in_abstract_ideas             1.029649
# starts_conversations                       1.015618
# uninterested_in_peoples_problems           1.140254
# get_chores_done                            1.052107
# easily_disturbed                           1.244839
# have_excellent_ideas                       0.559396
# have_little_to_say                         1.091628
# soft_hearted                               1.124473
# forget_to_put_things_back                  1.405040
# get_upset_easily                           1.351878
# no_good_imagination                        1.186381
# socialize_at_parties                       1.262885
# uninterested_in_others                     1.032844
# like_order                                 0.995256
# moody                                      1.277534
# quick_at_understanding_things              0.825275
# averts_attention_to_self                   1.353492
# take_time_out_for_others                   0.862766
# avoids_duties                              1.030241
# mood_swings                                1.448973
# use_difficult_words                        1.096106
# likes_being_center_of_attention            1.441164
# feel_others_emotions                       0.942361
# follows_schedule                           1.066405
# irritated_easily                           1.324969
# reflects_on_things                         0.899358
# quite_around_strangers                     1.208813
# make_people_feel_at_ease                   0.623985
# exacting_at_work                           0.780293
# feels_blue                                 1.137339
# full_of_ideas                              0.771078
# dtype: float64
#
#
# life_of_the_party                          1.0
# unconcerned_for_others                     1.0
# always_prepared                            1.0
# stressed_out_easily                        1.0
# have_rich_vocabulary                       1.0
# less_talkative                             1.0
# interested_in_people                       1.0
# leave_belongings_around                    1.0
# relaxed                                    1.0
# difficulty_understanding_abstract_ideas    1.0
# comfortable_around_people                  1.0
# insult_people                              1.0
# attention_to_detail                        1.0
# worrisome                                  1.0
# vivid_imagination                          1.0
# keep_in_the_background                     1.0
# sympathetic                                1.0
# messy_person                               1.0
# seldom_feel_blue                           1.0
# uninterested_in_abstract_ideas             1.0
# starts_conversations                       1.0
# uninterested_in_peoples_problems           1.0
# get_chores_done                            1.0
# easily_disturbed                           1.0
# have_excellent_ideas                       1.0
# have_little_to_say                         1.0
# soft_hearted                               1.0
# forget_to_put_things_back                  1.0
# get_upset_easily                           1.0
# no_good_imagination                        1.0
# socialize_at_parties                       1.0
# uninterested_in_others                     1.0
# like_order                                 1.0
# moody                                      1.0
# quick_at_understanding_things              1.0
# averts_attention_to_self                   1.0
# take_time_out_for_others                   1.0
# avoids_duties                              1.0
# mood_swings                                1.0
# use_difficult_words                        1.0
# likes_being_center_of_attention            1.0
# feel_others_emotions                       1.0
# follows_schedule                           1.0
# irritated_easily                           1.0
# reflects_on_things                         1.0
# quite_around_strangers                     1.0
# make_people_feel_at_ease                   1.0
# exacting_at_work                           1.0
# feels_blue                                 1.0
# full_of_ideas                              1.0
# dtype: float64

# %% [markdown]
# <h4>Scaling the Hult DNA explanatory variables</h4>

# %%
#Instantiating a StandartScaler object
scaler = StandardScaler()

#Fitting the scaler object to the explanatory data
scaler.fit(survey_answers_hultdna)

#Transforming the fit data
survey_answers_hultdna_scaled = scaler.transform(survey_answers_hultdna)

#Converting into a dataframe object
survey_answers_hultdna_scaled_df = pd.DataFrame(survey_answers_hultdna_scaled)

#Renaming the columns 
survey_answers_hultdna_scaled_df.columns = survey_answers_hultdna.columns

#Checking the variance before and after scaling
print(pd.np.var(survey_answers_hultdna))
print("\n")
print(pd.np.var(survey_answers_hultdna_scaled_df))
# Out:
# sees_underlying_patters_in_complex_situations               0.671908
# dont_generate_new_ideas                                     1.102763
# aware_of_personal_strengths/weakness                        0.604585
# growth_mindset                                              0.596939
# responds_effectively_to_priorities                          0.648161
# takes_initiative                                            0.818142
# encourages_direct/open_discussions                          0.652124
# responds_effectively_to_priorities(duplicate)               0.522432
# takes_initiative(duplicate)                                 0.771131
# encourages_direct/open_discussions(duplicate)               0.627447
# good_listener                                               0.659250
# dont_persuasively_sell_vision/idea                          1.059350
# builds_cooperative_relationships                            0.574910
# works_well_with_people_from_diverse_cultures                0.464123
# effectively_negotiates_interests/resources/roles            0.588687
# cant_rally_team_towards_common_goal                         1.209125
# translates_ideas_into_plans_that_are_organized/realistic    0.620028
# resolves_conflicts_constructively                           0.524619
# seeks/uses_teammates_feedback                               0.641966
# coaches_teammates_for_performance/growth                    0.767694
# drive_for_results                                           0.556747
# dtype: float64
#
#
# sees_underlying_patters_in_complex_situations               1.0
# dont_generate_new_ideas                                     1.0
# aware_of_personal_strengths/weakness                        1.0
# growth_mindset                                              1.0
# responds_effectively_to_priorities                          1.0
# takes_initiative                                            1.0
# encourages_direct/open_discussions                          1.0
# responds_effectively_to_priorities(duplicate)               1.0
# takes_initiative(duplicate)                                 1.0
# encourages_direct/open_discussions(duplicate)               1.0
# good_listener                                               1.0
# dont_persuasively_sell_vision/idea                          1.0
# builds_cooperative_relationships                            1.0
# works_well_with_people_from_diverse_cultures                1.0
# effectively_negotiates_interests/resources/roles            1.0
# cant_rally_team_towards_common_goal                         1.0
# translates_ideas_into_plans_that_are_organized/realistic    1.0
# resolves_conflicts_constructively                           1.0
# seeks/uses_teammates_feedback                               1.0
# coaches_teammates_for_performance/growth                    1.0
# drive_for_results                                           1.0
# dtype: float64

# %% [markdown]
# <br><br><br><strong>Creating a correlation heatmap</strong>

# %%
#Setting plot size
#fig, ax = plt.subplots(figsize = (12, 12))


#Developing a correlation matrix object
#survey_answers_scaled_df_corr = survey_answers_scaled_df.corr().round(2).iloc[0:19, 0:19]


#Creating a correlation heatmap
#sns.heatmap(survey_answers_scaled_df_corr,
#            cmap   = 'coolwarm',
#            square = True,
#            annot  = True)

#Display the heatmap
#plt.show()

# %%
#Setting plot size
#fig, ax = plt.subplots(figsize = (12, 12))


#Developing a correlation matrix object
#survey_answers_scaled_df_corr = survey_answers_scaled_df.corr().round(2).iloc[20:39, 20:39]


#Creating a correlation heatmap
#sns.heatmap(survey_answers_scaled_df_corr,
#            cmap   = 'coolwarm',
#            square = True,
#            annot  = True)

#Display the heatmap
#plt.show()

# %%
#Setting plot size
#fig, ax = plt.subplots(figsize = (12, 12))


#Developing a correlation matrix object
#survey_answers_scaled_df_corr = survey_answers_scaled_df.corr().round(2).iloc[40:59, 40:59]


#Creating a correlation heatmap
#sns.heatmap(survey_answers_scaled_df_corr,
#            cmap   = 'coolwarm',
#            square = True,
#            annot  = True)

#Display the heatmap
#plt.show()

# %%
#Setting plot size
#fig, ax = plt.subplots(figsize = (12, 12))


#Developing a correlation matrix object
#survey_answers_scaled_df_corr = survey_answers_scaled_df.corr().round(2).iloc[60:71, 60:71]


#Creating a correlation heatmap
#sns.heatmap(survey_answers_scaled_df_corr,
#            cmap   = 'coolwarm',
#            square = True,
#            annot  = True)

#Display the heatmap
#plt.show()

# %% [markdown]
# <strong>As can be seen from the correlation heatmaps, there are only a few correlations that are above 0.5 or below -0.5. Implying that we could explain high degree of variance using only a few Principal Components in PCA.</strong>

# %% [markdown]
# <br><br><br>
# ***
# ***
# ***
# <h3>Principal Component Analysis</h3>
#
# ***
# ***
# ***

# %% [markdown]
# <h4>PCA performed on the whole survey_answers_scaled explanatory variables</h4>

# %%
#Instantiating a PCA object without specific mention of components
#pca = PCA(n_components = None,
#          random_state = 222)

#Fitting and Transforming the scaled survey data
#pca_survey = pca.fit_transform(survey_answers_scaled)

#Comparing shapes
#print("Original shape:", survey_answers_scaled.shape)
#print("PCA shape     :", pca_survey.shape)

# %% [markdown]
# <br><br><br><strong>Plotting a Scree plot to visually detect the number of principal components to be used.</strong>

# %%
#Calling the scree plot function
#scree_plot(pca_object=pca)

# %% [markdown]
# <strong>Based on the Scree plot, it is a good choice to go with 7 Principal Components, as seen by the elbow of the plot at 7 PCA feature, after which there is very less change in explained variance.</strong>

# %%
#Instanting a PCA object with just the first 7 PC's
#pca7 = PCA(n_components = 7,
#           random_state = 222)

#Fitting and Transforming the scaled survey data
#pca7_survey = pca7.fit_transform(survey_answers_scaled)

# %% [markdown]
# <br><br><strong>Checking each components explained Variance ratio</strong>

# %%
#Component number counter
#component_number = 0


#Looping over each principal component
#for variance in pca7.explained_variance_ratio_:
#    component_number += 1
#    print(f"PC {component_number} : {variance.round(3)}")

# %% [markdown]
# <br><br><br><strong>Understanding the meaning of each principal component by analyzing its factor loading</strong>

# %%
#Transposing pca components
#factor_loadings_df = pd.DataFrame(pd.np.transpose(pca7.components_))


#Naming rows as original features
#factor_loadings_df = factor_loadings_df.set_index(survey_answers_scaled_df.columns)


#Checking the result
#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 1
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,0][factor_loadings_df.iloc[:,0]>0.1].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,0][factor_loadings_df.iloc[:,0]<-0.18].sort_values(ascending = True))
#print("\n\n")

#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 2
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,1][factor_loadings_df.iloc[:,1]>0.25].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,1][factor_loadings_df.iloc[:,1]<-0.07].sort_values(ascending = True))
#print("\n\n")

#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 3
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,2][factor_loadings_df.iloc[:,2]>0.15].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,2][factor_loadings_df.iloc[:,2]<-0.16].sort_values(ascending = True))
#print("\n\n")

#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 4
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,3][factor_loadings_df.iloc[:,3]>0.19].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,3][factor_loadings_df.iloc[:,3]<-0.16].sort_values(ascending = True))
#print("\n\n")

#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 5
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,4][factor_loadings_df.iloc[:,4]>0.19].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,4][factor_loadings_df.iloc[:,4]<-0.11].sort_values(ascending = True))
#print("\n\n")

#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 6
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,5][factor_loadings_df.iloc[:,5]>0.18].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,5][factor_loadings_df.iloc[:,5]<-0.14].sort_values(ascending = True))
#print("\n\n")

#print(f"""
#---------------------------------------
#FACTOR LOADING: PRINCIPAL COMPONENT 7
#---------------------------------------""")
#print(factor_loadings_df.iloc[:,6][factor_loadings_df.iloc[:,6]>0.18].sort_values(ascending = False))
#print("\n")
#print(factor_loadings_df.iloc[:,6][factor_loadings_df.iloc[:,6]<-0.14].sort_values(ascending = True))
#print("\n\n")

# %%
#Naming the Principal Components based on the factor loadings 
#factor_loadings_df.columns = ['uninterested_folks',
#                              'moody_folks',
#                              'Introverts',
#                              'people-centric/sympathetic_folks',
#                              'relaxed/self-centric_folks',
#                              'unimaginative_folks',
#                              'commanding_speakers']

#factor_loadings_df

# %% [markdown]
# <br><br><br><strong>Analyzing how each surveyor fits into each of the Principal Components</strong>

# %%
#Converting the earlier fit and transformed pca7 object into a Dataframe
#pca7_survey_df = pd.DataFrame(pca7_survey)

#Renaming columns
#pca7_survey_df.columns = factor_loadings_df.columns

#Displaying the results
#pca7_survey_df

# %% [markdown]
# <br><br><br><h4>PCA performed on the survey_answers_big5_scaled explanatory variables</h4>

# %%
#Instantiating a PCA object without specific mention of components
pca = PCA(n_components = None,
          random_state = 222)

#Fitting and Transforming the scaled survey data
pca_survey_big5 = pca.fit_transform(survey_answers_big5_scaled)

#Comparing shapes
print("Original shape:", survey_answers_big5_scaled.shape)
print("PCA shape     :", pca_survey_big5.shape)
# Out:
# Original shape: (392, 50)
# PCA shape     : (392, 50)

# %% [markdown]
# <br><br><br><strong>Plotting a Scree plot to visually detect the number of principal components to be used.</strong>

# %%
#Calling the scree plot function
scree_plot(pca_object=pca)

# %% [markdown]
# <strong>Based on the Scree plot, it is a good choice to go with 7 Principal Components, as seen by the elbow of the plot at 7 PCA feature, after which there is very less change in explained variance.</strong>

# %%
#Instanting a PCA object with just the first 7 PC's
pca7 = PCA(n_components = 7,
           random_state = 222)

#Fitting and Transforming the scaled survey data
pca7_survey_big5 = pca7.fit_transform(survey_answers_big5_scaled)

# %% [markdown]
# <br><br><strong>Checking each components explained Variance ratio</strong>

# %%
#Component number counter
component_number = 0


#Looping over each principal component
for variance in pca7.explained_variance_ratio_:
    component_number += 1
    print(f"PC {component_number} : {variance.round(3)}")
# Out:
# PC 1 : 0.129
# PC 2 : 0.084
# PC 3 : 0.072
# PC 4 : 0.055
# PC 5 : 0.05
# PC 6 : 0.04
# PC 7 : 0.034

# %% [markdown]
# <br><br><br><strong>Understanding the meaning of each principal component by analyzing its factor loading</strong>

# %%
#Transposing pca components
factor_loadings_big5_df = pd.DataFrame(pd.np.transpose(pca7.components_))


#Naming rows as original features
factor_loadings_big5_df = factor_loadings_big5_df.set_index(survey_answers_big5_scaled_df.columns)


#Checking the result
print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 1
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,0][factor_loadings_big5_df.iloc[:,0]>0.16].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,0][factor_loadings_big5_df.iloc[:,0]<-0.17].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 2
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,1][factor_loadings_big5_df.iloc[:,1]>0.25].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,1][factor_loadings_big5_df.iloc[:,1]<-0.07].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 3
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,2][factor_loadings_big5_df.iloc[:,2]>0.15].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,2][factor_loadings_big5_df.iloc[:,2]<-0.16].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 4
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,3][factor_loadings_big5_df.iloc[:,3]>0.19].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,3][factor_loadings_big5_df.iloc[:,3]<-0.16].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 5
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,4][factor_loadings_big5_df.iloc[:,4]>0.19].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,4][factor_loadings_big5_df.iloc[:,4]<-0.11].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 6
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,5][factor_loadings_big5_df.iloc[:,5]>0.18].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,5][factor_loadings_big5_df.iloc[:,5]<-0.1].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 7
---------------------------------------""")
print(factor_loadings_big5_df.iloc[:,6][factor_loadings_big5_df.iloc[:,6]>0.18].sort_values(ascending = False))
print("\n")
print(factor_loadings_big5_df.iloc[:,6][factor_loadings_big5_df.iloc[:,6]<-0.14].sort_values(ascending = True))
print("\n\n")
# Out:
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 1
# ---------------------------------------
# easily_disturbed                  0.190828
# get_upset_easily                  0.187856
# uninterested_in_others            0.186987
# uninterested_in_abstract_ideas    0.180580
# have_little_to_say                0.176494
# quite_around_strangers            0.172828
# mood_swings                       0.168912
# less_talkative                    0.160155
# Name: 0, dtype: float64
#
#
# comfortable_around_people   -0.211625
# starts_conversations        -0.204033
# make_people_feel_at_ease    -0.173915
# have_excellent_ideas        -0.173095
# feel_others_emotions        -0.171511
# Name: 0, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 2
# ---------------------------------------
# mood_swings            0.334983
# moody                  0.317542
# get_upset_easily       0.272259
# irritated_easily       0.264165
# stressed_out_easily    0.260212
# Name: 1, dtype: float64
#
#
# relaxed                            -0.133087
# uninterested_in_others             -0.131520
# uninterested_in_peoples_problems   -0.105956
# no_good_imagination                -0.087358
# less_talkative                     -0.076347
# Name: 1, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 3
# ---------------------------------------
# quite_around_strangers      0.279906
# less_talkative              0.252575
# attention_to_detail         0.229435
# keep_in_the_background      0.226899
# reflects_on_things          0.185739
# worrisome                   0.170216
# averts_attention_to_self    0.163362
# Name: 2, dtype: float64
#
#
# socialize_at_parties              -0.291415
# life_of_the_party                 -0.271499
# starts_conversations              -0.268604
# forget_to_put_things_back         -0.241624
# comfortable_around_people         -0.240720
# likes_being_center_of_attention   -0.227321
# leave_belongings_around           -0.180034
# messy_person                      -0.164824
# Name: 2, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 4
# ---------------------------------------
# use_difficult_words       0.272832
# have_rich_vocabulary      0.221538
# uninterested_in_others    0.219385
# always_prepared           0.197885
# Name: 3, dtype: float64
#
#
# interested_in_people                      -0.256085
# difficulty_understanding_abstract_ideas   -0.244230
# sympathetic                               -0.240970
# soft_hearted                              -0.235257
# feel_others_emotions                      -0.204137
# keep_in_the_background                    -0.200769
# have_little_to_say                        -0.188550
# Name: 3, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 5
# ---------------------------------------
# relaxed                             0.348304
# have_excellent_ideas                0.265062
# leave_belongings_around             0.250932
# full_of_ideas                       0.244417
# vivid_imagination                   0.211639
# messy_person                        0.201052
# uninterested_in_peoples_problems    0.201031
# Name: 4, dtype: float64
#
#
# stressed_out_easily                       -0.218119
# follows_schedule                          -0.201545
# uninterested_in_abstract_ideas            -0.200132
# difficulty_understanding_abstract_ideas   -0.185099
# worrisome                                 -0.135336
# get_chores_done                           -0.118349
# Name: 4, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 6
# ---------------------------------------
# get_chores_done                   0.319017
# no_good_imagination               0.306038
# follows_schedule                  0.295739
# uninterested_in_abstract_ideas    0.281911
# like_order                        0.268976
# always_prepared                   0.264963
# exacting_at_work                  0.212499
# life_of_the_party                 0.204361
# attention_to_detail               0.181164
# Name: 5, dtype: float64
#
#
# vivid_imagination    -0.196079
# reflects_on_things   -0.131828
# Name: 5, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 7
# ---------------------------------------
# follows_schedule                   0.259363
# likes_being_center_of_attention    0.237788
# full_of_ideas                      0.227144
# have_excellent_ideas               0.198221
# Name: 6, dtype: float64
#
#
# averts_attention_to_self        -0.399917
# have_rich_vocabulary            -0.355379
# insult_people                   -0.255195
# use_difficult_words             -0.233335
# quick_at_understanding_things   -0.220234
# take_time_out_for_others        -0.156233
# Name: 6, dtype: float64

# %%
#Naming the columns based on the factor loadings
factor_loadings_big5_df.columns = ['prefer_isolation',
                                   'moody',
                                   'non_party_person',
                                   'strong_verbal_aptitude',
                                   'relaxed',
                                   'systematic',
                                   'creative']

factor_loadings_big5_df
# Out:
#                                          prefer_isolation     moody  \
# life_of_the_party                               -0.070471  0.133817
# unconcerned_for_others                           0.122856 -0.013777
# always_prepared                                 -0.126274 -0.006365
# stressed_out_easily                              0.134607  0.260212
# have_rich_vocabulary                            -0.144728  0.033856
# less_talkative                                   0.160155 -0.076347
# interested_in_people                            -0.162506  0.122071
# leave_belongings_around                          0.073242  0.077537
# relaxed                                         -0.065350 -0.133087
# difficulty_understanding_abstract_ideas          0.128574  0.079829
# comfortable_around_people                       -0.211625 -0.002026
# insult_people                                    0.147033  0.034051
# attention_to_detail                             -0.139291  0.040939
# worrisome                                        0.050816  0.243860
# vivid_imagination                               -0.083586  0.210127
# keep_in_the_background                           0.150916  0.030922
# sympathetic                                     -0.163721  0.197102
# messy_person                                     0.155409  0.167568
# seldom_feel_blue                                -0.006196 -0.050022
# uninterested_in_abstract_ideas                   0.180580 -0.055791
# starts_conversations                            -0.204033  0.110650
# uninterested_in_peoples_problems                 0.140338 -0.105956
# get_chores_done                                 -0.112143  0.028117
# easily_disturbed                                 0.190828  0.159448
# have_excellent_ideas                            -0.173095  0.097631
# have_little_to_say                               0.176494 -0.036000
# soft_hearted                                    -0.093372  0.170557
# forget_to_put_things_back                        0.130656  0.054751
# get_upset_easily                                 0.187856  0.272259
# no_good_imagination                              0.112959 -0.087358
# socialize_at_parties                            -0.117776  0.109215
# uninterested_in_others                           0.186987 -0.131520
# like_order                                      -0.103623  0.052494
# moody                                            0.129361  0.317542
# quick_at_understanding_things                   -0.135417  0.019941
# averts_attention_to_self                         0.069355 -0.047720
# take_time_out_for_others                        -0.116326  0.100647
# avoids_duties                                    0.136298  0.112622
# mood_swings                                      0.168912  0.334983
# use_difficult_words                             -0.025911  0.066612
# likes_being_center_of_attention                 -0.111260  0.117793
# feel_others_emotions                            -0.171511  0.217204
# follows_schedule                                -0.143778  0.011550
# irritated_easily                                 0.158239  0.264165
# reflects_on_things                              -0.162387  0.147171
# quite_around_strangers                           0.172828 -0.046126
# make_people_feel_at_ease                        -0.173915  0.098001
# exacting_at_work                                -0.119831  0.045118
# feels_blue                                       0.154786  0.235244
# full_of_ideas                                   -0.163121  0.105709
#
#                                          non_party_person  \
# life_of_the_party                               -0.271499
# unconcerned_for_others                          -0.069394
# always_prepared                                  0.034432
# stressed_out_easily                              0.054517
# have_rich_vocabulary                             0.019405
# less_talkative                                   0.252575
# interested_in_people                            -0.097357
# leave_belongings_around                         -0.180034
# relaxed                                         -0.070228
# difficulty_understanding_abstract_ideas         -0.011094
# comfortable_around_people                       -0.240720
# insult_people                                   -0.151366
# attention_to_detail                              0.229435
# worrisome                                        0.170216
# vivid_imagination                                0.091543
# keep_in_the_background                           0.226899
# sympathetic                                      0.106325
# messy_person                                    -0.164824
# seldom_feel_blue                                -0.043128
# uninterested_in_abstract_ideas                  -0.043744
# starts_conversations                            -0.268604
# uninterested_in_peoples_problems                -0.098623
# get_chores_done                                  0.066016
# easily_disturbed                                -0.023704
# have_excellent_ideas                             0.026234
# have_little_to_say                               0.084004
# soft_hearted                                     0.102520
# forget_to_put_things_back                       -0.241624
# get_upset_easily                                -0.007242
# no_good_imagination                             -0.118751
# socialize_at_parties                            -0.291415
# uninterested_in_others                          -0.058854
# like_order                                       0.138097
# moody                                           -0.033321
# quick_at_understanding_things                    0.046385
# averts_attention_to_self                         0.163362
# take_time_out_for_others                         0.056910
# avoids_duties                                   -0.104259
# mood_swings                                     -0.013557
# use_difficult_words                             -0.033690
# likes_being_center_of_attention                 -0.227321
# feel_others_emotions                             0.113542
# follows_schedule                                 0.130656
# irritated_easily                                 0.030247
# reflects_on_things                               0.185739
# quite_around_strangers                           0.279906
# make_people_feel_at_ease                         0.019667
# exacting_at_work                                 0.104525
# feels_blue                                       0.037146
# full_of_ideas                                    0.055741
#
#                                          strong_verbal_aptitude   relaxed  \
# life_of_the_party                                     -0.000063 -0.024013
# unconcerned_for_others                                 0.045497  0.138281
# always_prepared                                        0.197885 -0.054198
# stressed_out_easily                                    0.020678 -0.218119
# have_rich_vocabulary                                   0.221538  0.025223
# less_talkative                                        -0.029635  0.180296
# interested_in_people                                  -0.256085  0.055579
# leave_belongings_around                               -0.134570  0.250932
# relaxed                                               -0.103493  0.348304
# difficulty_understanding_abstract_ideas               -0.244230 -0.185099
# comfortable_around_people                             -0.159532 -0.013666
# insult_people                                          0.048963  0.020499
# attention_to_detail                                    0.081918 -0.077603
# worrisome                                             -0.059729 -0.135336
# vivid_imagination                                      0.099386  0.211639
# keep_in_the_background                                -0.200769  0.186620
# sympathetic                                           -0.240970  0.034096
# messy_person                                          -0.119887  0.201052
# seldom_feel_blue                                       0.072114  0.141836
# uninterested_in_abstract_ideas                        -0.099934 -0.200132
# starts_conversations                                  -0.017617  0.007143
# uninterested_in_peoples_problems                       0.179790  0.201031
# get_chores_done                                        0.065786 -0.118349
# easily_disturbed                                       0.031885  0.024755
# have_excellent_ideas                                   0.178195  0.265062
# have_little_to_say                                    -0.188550  0.134789
# soft_hearted                                          -0.235257  0.062384
# forget_to_put_things_back                             -0.054557  0.180392
# get_upset_easily                                       0.153985 -0.065562
# no_good_imagination                                   -0.121548 -0.048291
# socialize_at_parties                                  -0.030107  0.028629
# uninterested_in_others                                 0.219385  0.064458
# like_order                                             0.063610 -0.059989
# moody                                                  0.111596  0.024817
# quick_at_understanding_things                          0.159478  0.149840
# averts_attention_to_self                              -0.072758  0.187369
# take_time_out_for_others                              -0.146162  0.027770
# avoids_duties                                         -0.112221  0.103065
# mood_swings                                            0.084374 -0.017821
# use_difficult_words                                    0.272832  0.114035
# likes_being_center_of_attention                        0.126542 -0.097585
# feel_others_emotions                                  -0.204137 -0.006714
# follows_schedule                                       0.048220 -0.201545
# irritated_easily                                       0.186911 -0.046141
# reflects_on_things                                     0.014198  0.090373
# quite_around_strangers                                -0.040064  0.160280
# make_people_feel_at_ease                              -0.157374  0.142846
# exacting_at_work                                       0.088915  0.152785
# feels_blue                                             0.042943  0.031538
# full_of_ideas                                          0.182386  0.244417
#
#                                          systematic  creative
# life_of_the_party                          0.204361  0.050371
# unconcerned_for_others                    -0.022281  0.177942
# always_prepared                            0.264963  0.074808
# stressed_out_easily                       -0.049447 -0.011426
# have_rich_vocabulary                       0.003329 -0.355379
# less_talkative                             0.056068  0.135086
# interested_in_people                       0.032031 -0.096246
# leave_belongings_around                   -0.039803  0.132749
# relaxed                                    0.135042 -0.041457
# difficulty_understanding_abstract_ideas    0.132951  0.105571
# comfortable_around_people                  0.081074 -0.096685
# insult_people                              0.123663 -0.255195
# attention_to_detail                        0.181164  0.040815
# worrisome                                 -0.048285  0.032216
# vivid_imagination                         -0.196079  0.135646
# keep_in_the_background                     0.117529  0.094766
# sympathetic                               -0.035656  0.076720
# messy_person                               0.104292 -0.004182
# seldom_feel_blue                           0.160126 -0.011415
# uninterested_in_abstract_ideas             0.281911  0.006722
# starts_conversations                      -0.005746  0.022854
# uninterested_in_peoples_problems           0.104063  0.164661
# get_chores_done                            0.319017  0.160313
# easily_disturbed                          -0.016822  0.002622
# have_excellent_ideas                       0.008654  0.198221
# have_little_to_say                         0.149204  0.174575
# soft_hearted                              -0.042188 -0.057583
# forget_to_put_things_back                 -0.089241 -0.072172
# get_upset_easily                           0.000608 -0.044268
# no_good_imagination                        0.306038 -0.106412
# socialize_at_parties                       0.144437  0.060098
# uninterested_in_others                     0.088677  0.076408
# like_order                                 0.268976 -0.129674
# moody                                      0.047980 -0.080313
# quick_at_understanding_things              0.115210 -0.220234
# averts_attention_to_self                   0.166413 -0.399917
# take_time_out_for_others                   0.120250 -0.156233
# avoids_duties                              0.116860 -0.044496
# mood_swings                               -0.011286 -0.019995
# use_difficult_words                        0.098940 -0.233335
# likes_being_center_of_attention            0.067193  0.237788
# feel_others_emotions                      -0.000497 -0.055814
# follows_schedule                           0.295739  0.259363
# irritated_easily                           0.046518 -0.034888
# reflects_on_things                        -0.131828 -0.090406
# quite_around_strangers                     0.110121 -0.015457
# make_people_feel_at_ease                   0.129787  0.087861
# exacting_at_work                           0.212499 -0.009487
# feels_blue                                 0.097379  0.043354
# full_of_ideas                             -0.026675  0.227144

# %% [markdown]
# <br><br><br><strong>Analyzing how each surveyor fits into each of the Principal Components</strong>

# %%
#Converting the earlier fit and transformed pca7 object into a Dataframe
pca7_survey_big5_df = pd.DataFrame(pca7_survey_big5)

#Renaming columns
pca7_survey_big5_df.columns = factor_loadings_big5_df.columns

#Displaying the results
pca7_survey_big5_df
# Out:
#      prefer_isolation     moody  non_party_person  strong_verbal_aptitude  \
# 0            0.163166 -0.260266          0.387455                1.085446
# 1            0.753219  0.357543          2.044443                1.060509
# 2            0.993750 -4.483148         -2.417418                3.012941
# 3            0.253881  2.894208          0.520128               -1.797544
# 4            3.489476  1.268058         -1.779067                0.603904
# ..                ...       ...               ...                     ...
# 387         -3.215937 -1.116377          1.484496               -0.554004
# 388          3.370587 -0.678643         -0.230204                0.595241
# 389         -3.873181 -0.851443          3.136824               -0.844649
# 390         -6.128999 -1.289761         -1.266585               -1.272721
# 391          3.618243 -1.054735          1.186930               -2.101918
#
#       relaxed  systematic  creative
# 0   -1.601504    0.896288 -0.244559
# 1    1.821249    0.376099  1.057837
# 2   -0.231447    2.099992  0.239003
# 3    2.422311   -0.158532  1.705412
# 4   -0.006121    1.683310  0.021653
# ..        ...         ...       ...
# 387 -0.212076    0.490008 -0.042005
# 388 -0.810533   -0.182529 -0.271820
# 389  1.564527    0.421931  3.553197
# 390 -0.535967    1.267536  0.109639
# 391  1.585149    0.047104 -1.295308
#
# [392 rows x 7 columns]

# %% [markdown]
# <br><br><br><h4>PCA performed on the survey_answers_hultdna_scaled explanatory variables</h4>

# %%
#Instantiating a PCA object without specific mention of components
pca = PCA(n_components = None,
          random_state = 206)

#Fitting and Transforming the scaled survey data
pca_survey_hultdna = pca.fit_transform(survey_answers_hultdna_scaled)

#Comparing shapes
print("Original shape:", survey_answers_hultdna_scaled.shape)
print("PCA shape     :", pca_survey_hultdna.shape)
# Out:
# Original shape: (392, 21)
# PCA shape     : (392, 21)

# %% [markdown]
# <br><br><br><strong>Plotting a Scree plot to visually detect the number of principal components to be used.</strong>

# %%
#Calling the scree plot function
scree_plot(pca_object=pca)

# %% [markdown]
# <strong>Based on the Scree plot, it is a good choice to go with 4 Principal Components, as seen by the elbow of the plot at 4 PCA feature, after which there is very less change in explained variance.</strong>

# %%
#Instanting a PCA object with just the first 4 PC's
pca4 = PCA(n_components = 4,
           random_state = 222)

#Fitting and Transforming the scaled survey data
pca4_survey_hultdna = pca4.fit_transform(survey_answers_hultdna_scaled)

# %% [markdown]
# <br><br><strong>Checking each components explained Variance ratio</strong>

# %%
#Component number counter
component_number = 0


#Looping over each principal component
for variance in pca4.explained_variance_ratio_:
    component_number += 1
    print(f"PC {component_number} : {variance.round(3)}")
# Out:
# PC 1 : 0.336
# PC 2 : 0.078
# PC 3 : 0.067
# PC 4 : 0.054

# %% [markdown]
# <br><br><br><strong>Understanding the meaning of each principal component by analyzing its factor loading</strong>

# %%
#Transposing pca components
factor_loadings_hultdna_df = pd.DataFrame(pd.np.transpose(pca4.components_))


#Naming rows as original features
factor_loadings_hultdna_df = factor_loadings_hultdna_df.set_index(survey_answers_hultdna_scaled_df.columns)


#Checking the result
print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 1
---------------------------------------""")
print(factor_loadings_hultdna_df.iloc[:,0][factor_loadings_hultdna_df.iloc[:,0] > 0.05].sort_values(ascending = False))
print("\n")
print(factor_loadings_hultdna_df.iloc[:,0][factor_loadings_hultdna_df.iloc[:,0] < -0.23].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 2
---------------------------------------""")
print(factor_loadings_hultdna_df.iloc[:,1][factor_loadings_hultdna_df.iloc[:,1]>0.25].sort_values(ascending = False))
print("\n")
print(factor_loadings_hultdna_df.iloc[:,1][factor_loadings_hultdna_df.iloc[:,1]<-0.07].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 3
---------------------------------------""")
print(factor_loadings_hultdna_df.iloc[:,2][factor_loadings_hultdna_df.iloc[:,2]>0.15].sort_values(ascending = False))
print("\n")
print(factor_loadings_hultdna_df.iloc[:,2][factor_loadings_hultdna_df.iloc[:,2]<-0.1].sort_values(ascending = True))
print("\n\n")

print(f"""
---------------------------------------
FACTOR LOADING: PRINCIPAL COMPONENT 4
---------------------------------------""")
print(factor_loadings_hultdna_df.iloc[:,3][factor_loadings_hultdna_df.iloc[:,3]>0.19].sort_values(ascending = False))
print("\n")
print(factor_loadings_hultdna_df.iloc[:,3][factor_loadings_hultdna_df.iloc[:,3]<-0.16].sort_values(ascending = True))
print("\n\n")
# Out:
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 1
# ---------------------------------------
# dont_generate_new_ideas                0.080267
# dont_persuasively_sell_vision/idea     0.074569
# cant_rally_team_towards_common_goal    0.070147
# Name: 0, dtype: float64
#
#
# responds_effectively_to_priorities(duplicate)      -0.275576
# takes_initiative                                   -0.261696
# takes_initiative(duplicate)                        -0.258791
# encourages_direct/open_discussions                 -0.256175
# resolves_conflicts_constructively                  -0.255759
# encourages_direct/open_discussions(duplicate)      -0.252322
# responds_effectively_to_priorities                 -0.247252
# effectively_negotiates_interests/resources/roles   -0.245515
# coaches_teammates_for_performance/growth           -0.235774
# works_well_with_people_from_diverse_cultures       -0.232192
# builds_cooperative_relationships                   -0.232087
# Name: 0, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 2
# ---------------------------------------
# good_listener                                   0.400594
# works_well_with_people_from_diverse_cultures    0.346479
# dont_persuasively_sell_vision/idea              0.323239
# seeks/uses_teammates_feedback                   0.284405
# resolves_conflicts_constructively               0.256896
# Name: 1, dtype: float64
#
#
# takes_initiative(duplicate)                     -0.300070
# takes_initiative                                -0.263740
# responds_effectively_to_priorities              -0.218732
# encourages_direct/open_discussions              -0.205202
# encourages_direct/open_discussions(duplicate)   -0.185222
# responds_effectively_to_priorities(duplicate)   -0.185017
# sees_underlying_patters_in_complex_situations   -0.128837
# Name: 1, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 3
# ---------------------------------------
# dont_persuasively_sell_vision/idea               0.508987
# cant_rally_team_towards_common_goal              0.469300
# dont_generate_new_ideas                          0.449421
# takes_initiative                                 0.220978
# takes_initiative(duplicate)                      0.203744
# seeks/uses_teammates_feedback                    0.184227
# encourages_direct/open_discussions(duplicate)    0.177639
# Name: 2, dtype: float64
#
#
# drive_for_results                                          -0.220385
# translates_ideas_into_plans_that_are_organized/realistic   -0.178869
# works_well_with_people_from_diverse_cultures               -0.127541
# growth_mindset                                             -0.104864
# Name: 2, dtype: float64
#
#
#
#
# ---------------------------------------
# FACTOR LOADING: PRINCIPAL COMPONENT 4
# ---------------------------------------
# cant_rally_team_towards_common_goal                         0.448241
# drive_for_results                                           0.312096
# seeks/uses_teammates_feedback                               0.281576
# translates_ideas_into_plans_that_are_organized/realistic    0.195625
# Name: 3, dtype: float64
#
#
# dont_generate_new_ideas                            -0.527955
# effectively_negotiates_interests/resources/roles   -0.242322
# works_well_with_people_from_diverse_cultures       -0.211403
# builds_cooperative_relationships                   -0.206816
# good_listener                                      -0.186726
# Name: 3, dtype: float64

# %%
factor_loadings_hultdna_df.columns = ['not_so_bright',
                                      'growth_mindset',
                                      'unconvincing',
                                      'inefficient']

factor_loadings_hultdna_df
# Out:
#                                                     not_so_bright  \
# sees_underlying_patters_in_complex_situations           -0.200906
# dont_generate_new_ideas                                  0.080267
# aware_of_personal_strengths/weakness                    -0.214944
# growth_mindset                                          -0.227228
# responds_effectively_to_priorities                      -0.247252
# takes_initiative                                        -0.261696
# encourages_direct/open_discussions                      -0.256175
# responds_effectively_to_priorities(duplicate)           -0.275576
# takes_initiative(duplicate)                             -0.258791
# encourages_direct/open_discussions(duplicate)           -0.252322
# good_listener                                           -0.157293
# dont_persuasively_sell_vision/idea                       0.074569
# builds_cooperative_relationships                        -0.232087
# works_well_with_people_from_diverse_cultures            -0.232192
# effectively_negotiates_interests/resources/roles        -0.245515
# cant_rally_team_towards_common_goal                      0.070147
# translates_ideas_into_plans_that_are_organized/...      -0.223489
# resolves_conflicts_constructively                       -0.255759
# seeks/uses_teammates_feedback                           -0.203765
# coaches_teammates_for_performance/growth                -0.235774
# drive_for_results                                       -0.194390
#
#                                                     growth_mindset  \
# sees_underlying_patters_in_complex_situations            -0.128837
# dont_generate_new_ideas                                   0.059266
# aware_of_personal_strengths/weakness                     -0.002692
# growth_mindset                                           -0.033619
# responds_effectively_to_priorities                       -0.218732
# takes_initiative                                         -0.263740
# encourages_direct/open_discussions                       -0.205202
# responds_effectively_to_priorities(duplicate)            -0.185017
# takes_initiative(duplicate)                              -0.300070
# encourages_direct/open_discussions(duplicate)            -0.185222
# good_listener                                             0.400594
# dont_persuasively_sell_vision/idea                        0.323239
# builds_cooperative_relationships                          0.242454
# works_well_with_people_from_diverse_cultures              0.346479
# effectively_negotiates_interests/resources/roles          0.143166
# cant_rally_team_towards_common_goal                       0.129396
# translates_ideas_into_plans_that_are_organized/...        0.053957
# resolves_conflicts_constructively                         0.256896
# seeks/uses_teammates_feedback                             0.284405
# coaches_teammates_for_performance/growth                  0.121025
# drive_for_results                                         0.123244
#
#                                                     unconvincing  inefficient
# sees_underlying_patters_in_complex_situations          -0.083049     0.128559
# dont_generate_new_ideas                                 0.449421    -0.527955
# aware_of_personal_strengths/weakness                    0.126075    -0.082147
# growth_mindset                                         -0.104864     0.118858
# responds_effectively_to_priorities                      0.071323    -0.035643
# takes_initiative                                        0.220978     0.135066
# encourages_direct/open_discussions                      0.066068    -0.083617
# responds_effectively_to_priorities(duplicate)           0.110332    -0.081618
# takes_initiative(duplicate)                             0.203744     0.004611
# encourages_direct/open_discussions(duplicate)           0.177639    -0.148306
# good_listener                                          -0.061644    -0.186726
# dont_persuasively_sell_vision/idea                      0.508987     0.122749
# builds_cooperative_relationships                       -0.055707    -0.206816
# works_well_with_people_from_diverse_cultures           -0.127541    -0.211403
# effectively_negotiates_interests/resources/roles       -0.046035    -0.242322
# cant_rally_team_towards_common_goal                     0.469300     0.448241
# translates_ideas_into_plans_that_are_organized/...     -0.178869     0.195625
# resolves_conflicts_constructively                       0.039675     0.049787
# seeks/uses_teammates_feedback                           0.184227     0.281576
# coaches_teammates_for_performance/growth               -0.005556     0.119178
# drive_for_results                                      -0.220385     0.312096

# %% [markdown]
# <br><br><br><strong>Analyzing how each surveyor fits into each of the Principal Components</strong>

# %%
#Converting the earlier fit and transformed pca7 object into a Dataframe
pca4_survey_hultdna_df = pd.DataFrame(pca4_survey_hultdna)

#Renaming columns
pca4_survey_hultdna_df.columns = factor_loadings_hultdna_df.columns

#Displaying the results
pca4_survey_hultdna_df
# Out:
#      not_so_bright  growth_mindset  unconvincing  inefficient
# 0         0.002541       -0.289953     -0.099617     0.043239
# 1        -1.186671       -0.570029      0.232524     1.384595
# 2         2.777220       -1.030334     -1.691554    -0.371834
# 3        -2.112491        2.126098      1.558631     0.568255
# 4         4.199188        0.018369      1.781101    -0.474963
# ..             ...             ...           ...          ...
# 387       1.996043       -0.191462     -0.644337     0.001651
# 388       0.210548       -0.255782      1.115379    -0.266251
# 389      -4.846997        0.234791      1.247980     2.084884
# 390      -4.233640        1.226943     -0.952484     0.319997
# 391       2.580468       -0.810488     -1.950699    -1.744510
#
# [392 rows x 4 columns]

# %% [markdown]
# <br><br><br><h3>Clustering</h3>

# %% [markdown]
# <h4>Clustering using the chosen 7 Principal components of the survey answers explanatory variables</h4>

# %%
#Checking the variance of the pca7_survey object
#pd.np.var(pca7_survey_df)

# %% [markdown]
# <strong>Rescaling our data, as the variance among features is no longer same in the new dataset.</strong>

# %%
#Instantiating a Standard Scaler object
#scaler = StandardScaler()

#Fitting the scaler object to the dataset
#scaler.fit(pca7_survey_df)

#Transforming the fit data
#pca7_survey_scaled = scaler.transform(pca7_survey_df)

#Converting it into a dataframe
#pca7_survey_scaled_df = pd.DataFrame(pca7_survey_scaled)

#Renaming the columns
#pca7_survey_scaled_df.columns = factor_loadings_df.columns

#Checking the variance
#pd.np.var(pca7_survey_scaled_df)

# %% [markdown]
# <br><br><strong>Creating a dendogram to determine the number of cluster for KNN modeling</strong>

# %%
#Grouping data based on Ward distance
#standard_mergings_ward = linkage(y = pca7_survey_scaled_df,
#                                 method = 'ward')


#Setting plot size
#fig, ax = plt.subplots(figsize=(12, 12))

#Developing a dendrogram
#dendrogram(Z = standard_mergings_ward,
#           leaf_rotation = 90,
#           leaf_font_size = 6)

#plt.show()

# %% [markdown]
# <strong>Plotting an inertia plot to see viable candidates for determining the number of clusters to be used in KMeans modeling</strong>

# %%
#Calling the inertia_plot function
#inertia_plot(data = pca7_survey_scaled_df)

# %% [markdown]
# <strong>Based on the inertia plot, lets use 5 clusters for building the KMeans model</strong>

# %%
#INSTANTIATING a k-Means object with five clusters
#survey_answers_kmeans_pca = KMeans(n_clusters = 5,
#                              random_state = 222)


#Fitting the object to the data
#survey_answers_kmeans_pca.fit(pca7_survey_scaled_df)


#Converting the clusters to a DataFrame
#survey_answers_kmeans_pca_df = pd.DataFrame({'Cluster': survey_answers_kmeans_pca.labels_})


#Checking the results
#print(survey_answers_kmeans_pca_df.iloc[: , 0].value_counts())

# %% [markdown]
# <strong>Finding the centroids of each cluster, in an attempt to explain the underlying story of ideal members of each cluster.</strong>

# %%
#Creating an object to store the cluster centers
#centroids_survey_answers_kmeans_pca = survey_answers_kmeans_pca.cluster_centers_

#Converting cluster centers into a dataframe
#centroids_survey_answers_kmeans_pca_df = pd.DataFrame(centroids_survey_answers_kmeans_pca)

#Renaming the columns
#centroids_survey_answers_kmeans_pca_df.columns = pca7_survey_scaled_df.columns

#Checking the results
#centroids_survey_answers_kmeans_pca_df

# %%
#Concatenating the cluster and PCA components
#cluster_pca_df = pd.concat([survey_answers_kmeans_pca_df,
#                           pca7_survey_df],
#                           axis = 1)

#Checking the results
#cluster_pca_df

# %%
#Concatenating the earlier eliminated columns
#final_cluster_pca_df = pd.concat([original_df.loc[:, ['target','current_laptop', 'surveyID', 'program', 'age', 'gender', 'nationality', 'ethnicity']],
#                                 cluster_pca_df], 
#                                 axis = 1)

#Checking the results
#final_cluster_pca_df

# %% [markdown]
# <h4>Clustering using the chosen 7 Principal components of the survey answers big5 personality traits explanatory variables</h4>

# %%
#Checking the variance of the pca7_survey object
pd.np.var(pca7_survey_big5_df)
# Out:
# prefer_isolation          6.440682
# moody                     4.193332
# non_party_person          3.601184
# strong_verbal_aptitude    2.745168
# relaxed                   2.486520
# systematic                2.016174
# creative                  1.707309
# dtype: float64

# %% [markdown]
# <strong>Rescaling our data, as the variance among features is no longer same in the new dataset.</strong>

# %%
#Instantiating a Standard Scaler object
scaler = StandardScaler()

#Fitting the scaler object to the dataset
scaler.fit(pca7_survey_big5_df)

#Transforming the fit data
pca7_survey_big5_scaled = scaler.transform(pca7_survey_big5_df)

#Converting it into a dataframe
pca7_survey_big5_scaled_df = pd.DataFrame(pca7_survey_big5_scaled)

#Renaming the columns
pca7_survey_big5_scaled_df.columns = factor_loadings_big5_df.columns

#Checking the variance
pd.np.var(pca7_survey_big5_scaled_df)
# Out:
# prefer_isolation          1.0
# moody                     1.0
# non_party_person          1.0
# strong_verbal_aptitude    1.0
# relaxed                   1.0
# systematic                1.0
# creative                  1.0
# dtype: float64

# %% [markdown]
# <br><br><strong>Creating a dendogram to determine the number of cluster for KNN modeling</strong>

# %%
#Grouping data based on Ward distance
standard_mergings_ward = linkage(y = pca7_survey_big5_scaled_df,
                                 method = 'ward')


#Setting plot size
fig, ax = plt.subplots(figsize=(12, 12))

#Developing a dendrogram
dendrogram(Z = standard_mergings_ward,
           leaf_rotation = 90,
           leaf_font_size = 6)

plt.show()

# %% [markdown]
# <strong>Plotting an inertia plot to see viable candidates for determining the number of clusters to be used in KMeans modeling</strong>

# %%
#Calling the inertia_plot function
inertia_plot(data = pca7_survey_big5_scaled_df)

# %% [markdown]
# <strong>Based on the inertia plot, lets use 3 clusters for building the KMeans model</strong>

# %%
#INSTANTIATING a k-Means object with 3 clusters
survey_answers_big5_kmeans_pca = KMeans(n_clusters = 3,
                                        random_state = 222)


#Fitting the object to the data
survey_answers_big5_kmeans_pca.fit(pca7_survey_big5_scaled_df)


#Converting the clusters to a DataFrame
survey_answers_big5_kmeans_pca_df = pd.DataFrame({'Cluster': survey_answers_big5_kmeans_pca.labels_})


#Checking the results
print(survey_answers_big5_kmeans_pca_df.iloc[: , 0].value_counts())
# Out:
# 1    144
# 2    137
# 0    111
# Name: Cluster, dtype: int64

# %% [markdown]
# <strong>Finding the centroids of each cluster, in an attempt to explain the underlying story of ideal members of each cluster.</strong>

# %%
#Creating an object to store the cluster centers
centroids_survey_answers_big5_kmeans_pca = survey_answers_big5_kmeans_pca.cluster_centers_

#Converting cluster centers into a dataframe
centroids_survey_answers_big5_kmeans_pca_df = pd.DataFrame(centroids_survey_answers_big5_kmeans_pca)

#Renaming the columns
centroids_survey_answers_big5_kmeans_pca_df.columns = pca7_survey_big5_scaled_df.columns

#Checking the results
centroids_survey_answers_big5_kmeans_pca_df
# Out:
#    prefer_isolation     moody  non_party_person  strong_verbal_aptitude  \
# 0          0.077506  0.375179          0.770498               -0.134602
# 1          0.742348 -0.063185         -0.206898                0.287978
# 2         -0.843076 -0.237564         -0.406802               -0.193635
#
#     relaxed  systematic  creative
# 0  0.868928    0.282703 -0.102991
# 1 -0.422138   -0.148404  0.473503
# 2 -0.260315   -0.073064 -0.414251

# %%
#Concatenating the cluster and PCA components
cluster_pca_big5_df = pd.concat([survey_answers_big5_kmeans_pca_df,
                                pca7_survey_big5_df],
                                axis = 1)

#Checking the results
cluster_pca_big5_df
# Out:
#      Cluster  prefer_isolation     moody  non_party_person  \
# 0          1          0.163166 -0.260266          0.387455
# 1          0          0.753219  0.357543          2.044443
# 2          1          0.993750 -4.483148         -2.417418
# 3          0          0.253881  2.894208          0.520128
# 4          1          3.489476  1.268058         -1.779067
# ..       ...               ...       ...               ...
# 387        2         -3.215937 -1.116377          1.484496
# 388        1          3.370587 -0.678643         -0.230204
# 389        0         -3.873181 -0.851443          3.136824
# 390        2         -6.128999 -1.289761         -1.266585
# 391        0          3.618243 -1.054735          1.186930
#
#      strong_verbal_aptitude   relaxed  systematic  creative
# 0                  1.085446 -1.601504    0.896288 -0.244559
# 1                  1.060509  1.821249    0.376099  1.057837
# 2                  3.012941 -0.231447    2.099992  0.239003
# 3                 -1.797544  2.422311   -0.158532  1.705412
# 4                  0.603904 -0.006121    1.683310  0.021653
# ..                      ...       ...         ...       ...
# 387               -0.554004 -0.212076    0.490008 -0.042005
# 388                0.595241 -0.810533   -0.182529 -0.271820
# 389               -0.844649  1.564527    0.421931  3.553197
# 390               -1.272721 -0.535967    1.267536  0.109639
# 391               -2.101918  1.585149    0.047104 -1.295308
#
# [392 rows x 8 columns]

# %%
#Concatenating the earlier eliminated columns
final_cluster_pca_big5_df = pd.concat([original_df.loc[:, ['preferred_laptop','current_laptop', 'surveyID', 'program', 'age', 'gender', 'nationality', 'ethnicity']],
                                      cluster_pca_big5_df], 
                                      axis = 1)

#Checking the results
final_cluster_pca_big5_df
# Out:
#     preferred_laptop  current_laptop surveyID  \
# 0            Macbook         Macbook    a1000
# 1     Windows laptop  Windows laptop    a1001
# 2     Windows laptop  Windows laptop    a1002
# 3     Windows laptop  Windows laptop    a1003
# 4     Windows laptop         Macbook    a1004
# ..               ...             ...      ...
# 387   Windows laptop  Windows laptop    a1387
# 388          Macbook         Macbook    a1388
# 389          Macbook  Windows laptop    a1389
# 390   Windows laptop  Windows laptop    a1390
# 391   Windows laptop  Windows laptop    a1391
#
#                               program  age  gender nationality  \
# 0       DD (MIB & Business Analytics)   25  Female     ecuador
# 1         One year Business Analytics   27    Male     Ecuador
# 2         One year Business Analytics   25    Male      Indian
# 3         One year Business Analytics   26  Female      indian
# 4    DD (MBA & Disruptive innovation)   27    Male       China
# ..                                ...  ...     ...         ...
# 387     DD (MBA & Business Analytics)   37    Male        calm
# 388     DD (MIB & Business Analytics)   27  Female           .
# 389     DD (MIB & Business Analytics)   23    Male       India
# 390     DD (MIB & Business Analytics)   25    Male      INDIAN
# 391       One year Business Analytics   27  Female        Thai
#
#                ethnicity  Cluster  prefer_isolation     moody  \
# 0      Hispanic / Latino        1          0.163166 -0.260266
# 1      Hispanic / Latino        0          0.753219  0.357543
# 2    West Asian / Indian        1          0.993750 -4.483148
# 3    West Asian / Indian        0          0.253881  2.894208
# 4         Far east Asian        1          3.489476  1.268058
# ..                   ...      ...               ...       ...
# 387    Hispanic / Latino        2         -3.215937 -1.116377
# 388    White / Caucasian        1          3.370587 -0.678643
# 389  West Asian / Indian        0         -3.873181 -0.851443
# 390  West Asian / Indian        2         -6.128999 -1.289761
# 391       Far east Asian        0          3.618243 -1.054735
#
#      non_party_person  strong_verbal_aptitude   relaxed  systematic  creative
# 0            0.387455                1.085446 -1.601504    0.896288 -0.244559
# 1            2.044443                1.060509  1.821249    0.376099  1.057837
# 2           -2.417418                3.012941 -0.231447    2.099992  0.239003
# 3            0.520128               -1.797544  2.422311   -0.158532  1.705412
# 4           -1.779067                0.603904 -0.006121    1.683310  0.021653
# ..                ...                     ...       ...         ...       ...
# 387          1.484496               -0.554004 -0.212076    0.490008 -0.042005
# 388         -0.230204                0.595241 -0.810533   -0.182529 -0.271820
# 389          3.136824               -0.844649  1.564527    0.421931  3.553197
# 390         -1.266585               -1.272721 -0.535967    1.267536  0.109639
# 391          1.186930               -2.101918  1.585149    0.047104 -1.295308
#
# [392 rows x 16 columns]

# %% [markdown]
# <h4>Clustering using the chosen 4 Principal components of the survey answers hult dna explanatory variables</h4>

# %%
#Checking the variance of the pca7_survey object
pd.np.var(pca4_survey_hultdna_df)
# Out:
# not_so_bright     7.062184
# growth_mindset    1.643652
# unconvincing      1.401190
# inefficient       1.132304
# dtype: float64

# %% [markdown]
# <strong>Rescaling our data, as the variance among features is no longer same in the new dataset.</strong>

# %%
#Instantiating a Standard Scaler object
scaler = StandardScaler()

#Fitting the scaler object to the dataset
scaler.fit(pca4_survey_hultdna_df)

#Transforming the fit data
pca4_survey_hultdna_scaled = scaler.transform(pca4_survey_hultdna_df)

#Converting it into a dataframe
pca4_survey_hultdna_scaled_df = pd.DataFrame(pca4_survey_hultdna_scaled)

#Renaming the columns
pca4_survey_hultdna_scaled_df.columns = factor_loadings_hultdna_df.columns

#Checking the variance
pd.np.var(pca4_survey_hultdna_scaled_df)
# Out:
# not_so_bright     1.0
# growth_mindset    1.0
# unconvincing      1.0
# inefficient       1.0
# dtype: float64

# %% [markdown]
# <br><br><strong>Creating a dendogram to determine the number of cluster for KNN modeling</strong>

# %%
#Grouping data based on Ward distance
standard_mergings_ward = linkage(y = pca4_survey_hultdna_scaled_df,
                                 method = 'ward')


#Setting plot size
fig, ax = plt.subplots(figsize=(12, 12))

#Developing a dendrogram
dendrogram(Z = standard_mergings_ward,
           leaf_rotation = 90,
           leaf_font_size = 6)

plt.show()

# %% [markdown]
# <strong>Plotting an inertia plot to see viable candidates for determining the number of clusters to be used in KMeans modeling</strong>

# %%
#Calling the inertia_plot function
inertia_plot(data = pca4_survey_hultdna_scaled_df)

# %% [markdown]
# <strong>Based on the inertia plot, lets use 4 clusters for building the KMeans model</strong>

# %%
#INSTANTIATING a k-Means object with five clusters
survey_answers_hultdna_kmeans_pca = KMeans(n_clusters = 4,
                                           random_state = 222)


#Fitting the object to the data
survey_answers_hultdna_kmeans_pca.fit(pca4_survey_hultdna_scaled_df)


#Converting the clusters to a DataFrame
survey_answers_hultdna_kmeans_pca_df = pd.DataFrame({'Cluster': survey_answers_hultdna_kmeans_pca.labels_})


#Checking the results
print(survey_answers_hultdna_kmeans_pca_df.iloc[: , 0].value_counts())
# Out:
# 0    121
# 3    101
# 1     88
# 2     82
# Name: Cluster, dtype: int64

# %% [markdown]
# <strong>Finding the centroids of each cluster, in an attempt to explain the underlying story of ideal members of each cluster.</strong>

# %%
#Creating an object to store the cluster centers
centroids_survey_answers_hultdna_kmeans_pca = survey_answers_hultdna_kmeans_pca.cluster_centers_

#Converting cluster centers into a dataframe
centroids_survey_answers_hultdna_kmeans_pca_df = pd.DataFrame(centroids_survey_answers_hultdna_kmeans_pca)

#Renaming the columns
centroids_survey_answers_hultdna_kmeans_pca_df.columns = pca4_survey_hultdna_scaled_df.columns

#Checking the results
centroids_survey_answers_hultdna_kmeans_pca_df
# Out:
#    not_so_bright  growth_mindset  unconvincing  inefficient
# 0      -0.700426       -0.366444     -0.757627    -0.147677
# 1       0.839560        0.835135     -0.557224     0.007511
# 2      -0.508441        0.353751      0.839475     0.991063
# 3       0.520420       -0.575839      0.711600    -0.634249

# %%
#Concatenating the cluster and PCA components
cluster_pca_hultdna_df = pd.concat([survey_answers_hultdna_kmeans_pca_df,
                                   pca4_survey_hultdna_df],
                                   axis = 1)

#Checking the results
cluster_pca_hultdna_df
# Out:
#      Cluster  not_so_bright  growth_mindset  unconvincing  inefficient
# 0          0       0.002541       -0.289953     -0.099617     0.043239
# 1          2      -1.186671       -0.570029      0.232524     1.384595
# 2          1       2.777220       -1.030334     -1.691554    -0.371834
# 3          2      -2.112491        2.126098      1.558631     0.568255
# 4          3       4.199188        0.018369      1.781101    -0.474963
# ..       ...            ...             ...           ...          ...
# 387        1       1.996043       -0.191462     -0.644337     0.001651
# 388        3       0.210548       -0.255782      1.115379    -0.266251
# 389        2      -4.846997        0.234791      1.247980     2.084884
# 390        0      -4.233640        1.226943     -0.952484     0.319997
# 391        0       2.580468       -0.810488     -1.950699    -1.744510
#
# [392 rows x 5 columns]

# %%
#Concatenating the earlier eliminated columns
final_cluster_pca_hultdna_df = pd.concat([original_df.loc[:, ['preferred_laptop','current_laptop', 'surveyID', 'program', 'age', 'gender', 'nationality', 'ethnicity']],
                                         cluster_pca_hultdna_df], 
                                         axis = 1)

#Checking the results
final_cluster_pca_hultdna_df
# Out:
#     preferred_laptop  current_laptop surveyID  \
# 0            Macbook         Macbook    a1000
# 1     Windows laptop  Windows laptop    a1001
# 2     Windows laptop  Windows laptop    a1002
# 3     Windows laptop  Windows laptop    a1003
# 4     Windows laptop         Macbook    a1004
# ..               ...             ...      ...
# 387   Windows laptop  Windows laptop    a1387
# 388          Macbook         Macbook    a1388
# 389          Macbook  Windows laptop    a1389
# 390   Windows laptop  Windows laptop    a1390
# 391   Windows laptop  Windows laptop    a1391
#
#                               program  age  gender nationality  \
# 0       DD (MIB & Business Analytics)   25  Female     ecuador
# 1         One year Business Analytics   27    Male     Ecuador
# 2         One year Business Analytics   25    Male      Indian
# 3         One year Business Analytics   26  Female      indian
# 4    DD (MBA & Disruptive innovation)   27    Male       China
# ..                                ...  ...     ...         ...
# 387     DD (MBA & Business Analytics)   37    Male        calm
# 388     DD (MIB & Business Analytics)   27  Female           .
# 389     DD (MIB & Business Analytics)   23    Male       India
# 390     DD (MIB & Business Analytics)   25    Male      INDIAN
# 391       One year Business Analytics   27  Female        Thai
#
#                ethnicity  Cluster  not_so_bright  growth_mindset  \
# 0      Hispanic / Latino        0       0.002541       -0.289953
# 1      Hispanic / Latino        2      -1.186671       -0.570029
# 2    West Asian / Indian        1       2.777220       -1.030334
# 3    West Asian / Indian        2      -2.112491        2.126098
# 4         Far east Asian        3       4.199188        0.018369
# ..                   ...      ...            ...             ...
# 387    Hispanic / Latino        1       1.996043       -0.191462
# 388    White / Caucasian        3       0.210548       -0.255782
# 389  West Asian / Indian        2      -4.846997        0.234791
# 390  West Asian / Indian        0      -4.233640        1.226943
# 391       Far east Asian        0       2.580468       -0.810488
#
#      unconvincing  inefficient
# 0       -0.099617     0.043239
# 1        0.232524     1.384595
# 2       -1.691554    -0.371834
# 3        1.558631     0.568255
# 4        1.781101    -0.474963
# ..            ...          ...
# 387     -0.644337     0.001651
# 388      1.115379    -0.266251
# 389      1.247980     2.084884
# 390     -0.952484     0.319997
# 391     -1.950699    -1.744510
#
# [392 rows x 13 columns]

# %%
final_cluster_pca_hultdna_df[['growth_mindset', 'Cluster', 'current_laptop', 'preferred_laptop']][final_cluster_pca_hultdna_df['growth_mindset']>1.0][final_cluster_pca_hultdna_df['preferred_laptop']=='Windows laptop']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      growth_mindset  Cluster  current_laptop preferred_laptop
# 3          2.126098        2  Windows laptop   Windows laptop
# 27         1.118404        2         Macbook   Windows laptop
# 28         1.267688        0  Windows laptop   Windows laptop
# 56         2.630410        2  Windows laptop   Windows laptop
# 58         1.939095        1  Windows laptop   Windows laptop
# 91         1.083169        1  Windows laptop   Windows laptop
# 104        1.140658        1  Windows laptop   Windows laptop
# 118        2.678555        1  Windows laptop   Windows laptop
# 124        1.152128        1  Windows laptop   Windows laptop
# 136        1.398051        1  Windows laptop   Windows laptop
# 151        2.126098        2  Windows laptop   Windows laptop
# 175        1.118404        2         Macbook   Windows laptop
# 176        1.267688        0  Windows laptop   Windows laptop
# 204        2.630410        2  Windows laptop   Windows laptop
# 206        1.939095        1  Windows laptop   Windows laptop
# 239        1.083169        1  Windows laptop   Windows laptop
# 252        1.140658        1  Windows laptop   Windows laptop
# 266        2.678555        1  Windows laptop   Windows laptop
# 272        1.152128        1  Windows laptop   Windows laptop
# 284        1.398051        1  Windows laptop   Windows laptop
# 295        2.308137        1  Windows laptop   Windows laptop
# 303        3.586237        2  Windows laptop   Windows laptop
# 311        1.278980        2         Macbook   Windows laptop
# 321        1.978251        1  Windows laptop   Windows laptop
# 323        2.208341        1  Windows laptop   Windows laptop
# 324        1.561124        2  Windows laptop   Windows laptop
# 326        1.725711        0  Windows laptop   Windows laptop
# 334        1.060476        1  Windows laptop   Windows laptop
# 344        2.016233        2  Windows laptop   Windows laptop
# 348        3.115657        1  Windows laptop   Windows laptop
# 362        3.297655        1         Macbook   Windows laptop
# 369        2.672076        1  Windows laptop   Windows laptop
# 372        1.847552        1  Windows laptop   Windows laptop
# 386        1.070871        1         Macbook   Windows laptop
# 390        1.226943        0  Windows laptop   Windows laptop

# %%
final_cluster_pca_hultdna_df[['growth_mindset', 'Cluster', 'current_laptop', 'preferred_laptop']][final_cluster_pca_hultdna_df['growth_mindset']>1.0][final_cluster_pca_hultdna_df['preferred_laptop']=='Windows laptop']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      growth_mindset  Cluster  current_laptop preferred_laptop
# 3          2.126098        2  Windows laptop   Windows laptop
# 27         1.118404        2         Macbook   Windows laptop
# 28         1.267688        0  Windows laptop   Windows laptop
# 56         2.630410        2  Windows laptop   Windows laptop
# 58         1.939095        1  Windows laptop   Windows laptop
# 91         1.083169        1  Windows laptop   Windows laptop
# 104        1.140658        1  Windows laptop   Windows laptop
# 118        2.678555        1  Windows laptop   Windows laptop
# 124        1.152128        1  Windows laptop   Windows laptop
# 136        1.398051        1  Windows laptop   Windows laptop
# 151        2.126098        2  Windows laptop   Windows laptop
# 175        1.118404        2         Macbook   Windows laptop
# 176        1.267688        0  Windows laptop   Windows laptop
# 204        2.630410        2  Windows laptop   Windows laptop
# 206        1.939095        1  Windows laptop   Windows laptop
# 239        1.083169        1  Windows laptop   Windows laptop
# 252        1.140658        1  Windows laptop   Windows laptop
# 266        2.678555        1  Windows laptop   Windows laptop
# 272        1.152128        1  Windows laptop   Windows laptop
# 284        1.398051        1  Windows laptop   Windows laptop
# 295        2.308137        1  Windows laptop   Windows laptop
# 303        3.586237        2  Windows laptop   Windows laptop
# 311        1.278980        2         Macbook   Windows laptop
# 321        1.978251        1  Windows laptop   Windows laptop
# 323        2.208341        1  Windows laptop   Windows laptop
# 324        1.561124        2  Windows laptop   Windows laptop
# 326        1.725711        0  Windows laptop   Windows laptop
# 334        1.060476        1  Windows laptop   Windows laptop
# 344        2.016233        2  Windows laptop   Windows laptop
# 348        3.115657        1  Windows laptop   Windows laptop
# 362        3.297655        1         Macbook   Windows laptop
# 369        2.672076        1  Windows laptop   Windows laptop
# 372        1.847552        1  Windows laptop   Windows laptop
# 386        1.070871        1         Macbook   Windows laptop
# 390        1.226943        0  Windows laptop   Windows laptop

# %%
final_cluster_pca_hultdna_df[['growth_mindset', 'current_laptop', 'preferred_laptop']][final_cluster_pca_hultdna_df['growth_mindset']>1.0][final_cluster_pca_hultdna_df['preferred_laptop']=='Macbook ']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [growth_mindset, current_laptop, preferred_laptop]
# Index: []

# %% [markdown]
# <h3>Boxplots</h3>

# %% [markdown]
# <h4>Creating boxplots of the Principal components for the survey answers regarding Hult DNA, with regards to the current laptop that they posses</h4>

# %%
#not_so_bright_kid
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'not_so_bright_kid',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-b8152442e0a6> in <module>
#       4             y = 'not_so_bright_kid',
#       5             hue = 'Cluster',
# ----> 6             data = final_cluster_pca_hultdna_df)
#       7
#       8
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# --> 446         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     447         self.establish_colors(color, palette, saturation)
#     448
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'not_so_bright_kid'

# %%
#teamplayer
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'teamplayer',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %%
#unconvincing
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'unconvincing',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %%
#talented_but_not_a_teamplayer
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'talented_but_not_a_teamplayer',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Creating boxplots of the Principal components for the survey answers regarding Hult DNA, separated by future laptop choice</h4>

# %%
#talented_but_not_a_teamplayer
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'not_so_bright_kid',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %%
#teamplayer
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'teamplayer',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <strong>INSIGHT: For the "teamplayer" principal component, there is a big difference in mean between the surveyors who want to buy Chromebook, compared to the ones who wanna buy Macbook/Windows laptop, when asked this question. Implying, people belonging to this cluster as well as this particular principal component, have a desire to buy chromebook more than any other laptop.</strong><br><br><br>

# %%
#unconvincing
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'unconvincing',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <strong>INSIGHT: For the "unconvincing" principal component, for clusters 1 and 2, there tend to be fewer Chromebook buyers than Macbook/Windows, as seen by the lower mean line.</strong><br><br><br>

# %%
#talented_but_not_a_teamplayer
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'talented_but_not_a_teamplayer',
            hue = 'Cluster',
            data = final_cluster_pca_hultdna_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <strong>INSIGHT: For "talented_but_not_a_teamplayer" principal component, people belonging to cluster 1 tend to show a greater desire to buy Chromebook, than Macbook/Windows, as seen by the higher mean.</strong><br><br><br>

# %% [markdown]
# <h4>Creating boxplots of the Principal components for the big5 personality traits survey answers, separated by current laptop.</h4>

# %%
#uninterested
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'uninterested',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#moody
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'moody',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#introverts
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'introverts',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#predominant
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'predominant',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#creative_but_messy
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'creative_but_messy',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#systematic
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'systematic',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#respectful
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'current_laptop',
            y = 'respectful',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Creating boxplots of the Principal components for the big5 personality traits survey answers, separated by future laptop choice</h4>

# %%
#uninterested
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'uninterested',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#moody
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'moody',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <strong>People belonging to the "moody" principal component and cluster 0, show a big variance, however prefer to buy Chromebook.</strong><br><br><br>

# %%
#introverts
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'introverts',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %% [markdown]
# <strong>People belonging to the "introverts" component and to clusters 0, 1, do not prefer to buy the Chromebook and would like to buy the Windows or the Macbook.</strong><br><br><br>

# %%
#predominant
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'predominant',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#creative_but_messy
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'creative_but_messy',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#systematic
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'systematic',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()

# %%
#respectful
fig, ax = plt.subplots(figsize = (12, 8))
sns.boxplot(x = 'target',
            y = 'respectful',
            hue = 'Cluster',
            data = final_cluster_pca_big5_df)


plt.tight_layout()
plt.show()
